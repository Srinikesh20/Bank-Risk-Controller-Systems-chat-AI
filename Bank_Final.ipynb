# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix,precision_score,recall_score,f1_score,roc_auc_score,roc_curve
from sklearn.preprocessing import StandardScaler, OneHotEncoder,LabelBinarizer,OrdinalEncoder,LabelEncoder

from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv("loan_data.csv")

# %%
df.head(10)
# Out:
#    SK_ID_CURR  TARGET NAME_CONTRACT_TYPE_x CODE_GENDER FLAG_OWN_CAR  \
# 0      100002       1           Cash loans           M            N
# 1      100003       0           Cash loans           F            N
# 2      100003       0           Cash loans           F            N
# 3      100003       0           Cash loans           F            N
# 4      100004       0      Revolving loans           M            Y
# 5      100006       0           Cash loans           F            N
# 6      100006       0           Cash loans           F            N
# 7      100006       0           Cash loans           F            N
# 8      100006       0           Cash loans           F            N
# 9      100006       0           Cash loans           F            N
#
#   FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT_x  \
# 0               Y             0          202500.0      406597.5
# 1               N             0          270000.0     1293502.5
# 2               N             0          270000.0     1293502.5
# 3               N             0          270000.0     1293502.5
# 4               Y             0           67500.0      135000.0
# 5               Y             0          135000.0      312682.5
# 6               Y             0          135000.0      312682.5
# 7               Y             0          135000.0      312682.5
# 8               Y             0          135000.0      312682.5
# 9               Y             0          135000.0      312682.5
#
#    AMT_ANNUITY_x  ...  NAME_SELLER_INDUSTRY CNT_PAYMENT NAME_YIELD_GROUP  \
# 0        24700.5  ...       Auto technology        24.0       low_normal
# 1        35698.5  ...                   XNA        12.0       low_normal
# 2        35698.5  ...             Furniture         6.0           middle
# 3        35698.5  ...  Consumer electronics        12.0           middle
# 4         6750.0  ...          Connectivity         4.0           middle
# 5        29686.5  ...                   XNA        48.0       low_normal
# 6        29686.5  ...                   XNA         NaN              XNA
# 7        29686.5  ...  Consumer electronics        12.0             high
# 8        29686.5  ...                   XNA         0.0              XNA
# 9        29686.5  ...                   XNA        18.0             high
#
#            PRODUCT_COMBINATION DAYS_FIRST_DRAWING DAYS_FIRST_DUE  \
# 0      POS other with interest           365243.0         -565.0
# 1             Cash X-Sell: low           365243.0         -716.0
# 2   POS industry with interest           365243.0         -797.0
# 3  POS household with interest           365243.0        -2310.0
# 4  POS mobile without interest           365243.0         -784.0
# 5             Cash X-Sell: low           365243.0         -151.0
# 6                  Card Street                NaN            NaN
# 7  POS household with interest           365243.0         -281.0
# 8                  Card X-Sell           365243.0       365243.0
# 9            Cash X-Sell: high                NaN            NaN
#
#    DAYS_LAST_DUE_1ST_VERSION  DAYS_LAST_DUE  DAYS_TERMINATION  \
# 0                      125.0          -25.0             -17.0
# 1                     -386.0         -536.0            -527.0
# 2                     -647.0         -647.0            -639.0
# 3                    -1980.0        -1980.0           -1976.0
# 4                     -694.0         -724.0            -714.0
# 5                     1259.0         -151.0            -143.0
# 6                        NaN            NaN               NaN
# 7                       49.0       365243.0          365243.0
# 8                   365243.0       365243.0          365243.0
# 9                        NaN            NaN               NaN
#
#    NFLAG_INSURED_ON_APPROVAL
# 0                        0.0
# 1                        1.0
# 2                        0.0
# 3                        1.0
# 4                        0.0
# 5                        0.0
# 6                        NaN
# 7                        0.0
# 8                        0.0
# 9                        NaN
#
# [10 rows x 158 columns]

# %%
df.shape
# Out:
# (1413701, 158)

# %%
for column in df.columns:
    print(column)
# Out:
# SK_ID_CURR
# TARGET
# NAME_CONTRACT_TYPE_x
# CODE_GENDER
# FLAG_OWN_CAR
# FLAG_OWN_REALTY
# CNT_CHILDREN
# AMT_INCOME_TOTAL
# AMT_CREDIT_x
# AMT_ANNUITY_x
# AMT_GOODS_PRICE_x
# NAME_TYPE_SUITE_x
# NAME_INCOME_TYPE
# NAME_EDUCATION_TYPE
# NAME_FAMILY_STATUS
# NAME_HOUSING_TYPE
# REGION_POPULATION_RELATIVE
# DAYS_BIRTH
# DAYS_EMPLOYED
# DAYS_REGISTRATION
# DAYS_ID_PUBLISH
# OWN_CAR_AGE
# FLAG_MOBIL
# FLAG_EMP_PHONE
# FLAG_WORK_PHONE
# FLAG_CONT_MOBILE
# FLAG_PHONE
# FLAG_EMAIL
# OCCUPATION_TYPE
# CNT_FAM_MEMBERS
# REGION_RATING_CLIENT
# REGION_RATING_CLIENT_W_CITY
# WEEKDAY_APPR_PROCESS_START_x
# HOUR_APPR_PROCESS_START_x
# REG_REGION_NOT_LIVE_REGION
# REG_REGION_NOT_WORK_REGION
# LIVE_REGION_NOT_WORK_REGION
# REG_CITY_NOT_LIVE_CITY
# REG_CITY_NOT_WORK_CITY
# LIVE_CITY_NOT_WORK_CITY
# ORGANIZATION_TYPE
# EXT_SOURCE_1
# EXT_SOURCE_2
# EXT_SOURCE_3
# APARTMENTS_AVG
# BASEMENTAREA_AVG
# YEARS_BEGINEXPLUATATION_AVG
# YEARS_BUILD_AVG
# COMMONAREA_AVG
# ELEVATORS_AVG
# ENTRANCES_AVG
# FLOORSMAX_AVG
# FLOORSMIN_AVG
# LANDAREA_AVG
# LIVINGAPARTMENTS_AVG
# LIVINGAREA_AVG
# NONLIVINGAPARTMENTS_AVG
# NONLIVINGAREA_AVG
# APARTMENTS_MODE
# BASEMENTAREA_MODE
# YEARS_BEGINEXPLUATATION_MODE
# YEARS_BUILD_MODE
# COMMONAREA_MODE
# ELEVATORS_MODE
# ENTRANCES_MODE
# FLOORSMAX_MODE
# FLOORSMIN_MODE
# LANDAREA_MODE
# LIVINGAPARTMENTS_MODE
# LIVINGAREA_MODE
# NONLIVINGAPARTMENTS_MODE
# NONLIVINGAREA_MODE
# APARTMENTS_MEDI
# BASEMENTAREA_MEDI
# YEARS_BEGINEXPLUATATION_MEDI
# YEARS_BUILD_MEDI
# COMMONAREA_MEDI
# ELEVATORS_MEDI
# ENTRANCES_MEDI
# FLOORSMAX_MEDI
# FLOORSMIN_MEDI
# LANDAREA_MEDI
# LIVINGAPARTMENTS_MEDI
# LIVINGAREA_MEDI
# NONLIVINGAPARTMENTS_MEDI
# NONLIVINGAREA_MEDI
# FONDKAPREMONT_MODE
# HOUSETYPE_MODE
# TOTALAREA_MODE
# WALLSMATERIAL_MODE
# EMERGENCYSTATE_MODE
# OBS_30_CNT_SOCIAL_CIRCLE
# DEF_30_CNT_SOCIAL_CIRCLE
# OBS_60_CNT_SOCIAL_CIRCLE
# DEF_60_CNT_SOCIAL_CIRCLE
# DAYS_LAST_PHONE_CHANGE
# FLAG_DOCUMENT_2
# FLAG_DOCUMENT_3
# FLAG_DOCUMENT_4
# FLAG_DOCUMENT_5
# FLAG_DOCUMENT_6
# FLAG_DOCUMENT_7
# FLAG_DOCUMENT_8
# FLAG_DOCUMENT_9
# FLAG_DOCUMENT_10
# FLAG_DOCUMENT_11
# FLAG_DOCUMENT_12
# FLAG_DOCUMENT_13
# FLAG_DOCUMENT_14
# FLAG_DOCUMENT_15
# FLAG_DOCUMENT_16
# FLAG_DOCUMENT_17
# FLAG_DOCUMENT_18
# FLAG_DOCUMENT_19
# FLAG_DOCUMENT_20
# FLAG_DOCUMENT_21
# AMT_REQ_CREDIT_BUREAU_HOUR
# AMT_REQ_CREDIT_BUREAU_DAY
# AMT_REQ_CREDIT_BUREAU_WEEK
# AMT_REQ_CREDIT_BUREAU_MON
# AMT_REQ_CREDIT_BUREAU_QRT
# AMT_REQ_CREDIT_BUREAU_YEAR
# SK_ID_PREV
# NAME_CONTRACT_TYPE_y
# AMT_ANNUITY_y
# AMT_APPLICATION
# AMT_CREDIT_y
# AMT_DOWN_PAYMENT
# AMT_GOODS_PRICE_y
# WEEKDAY_APPR_PROCESS_START_y
# HOUR_APPR_PROCESS_START_y
# FLAG_LAST_APPL_PER_CONTRACT
# NFLAG_LAST_APPL_IN_DAY
# RATE_DOWN_PAYMENT
# RATE_INTEREST_PRIMARY
# RATE_INTEREST_PRIVILEGED
# NAME_CASH_LOAN_PURPOSE
# NAME_CONTRACT_STATUS
# DAYS_DECISION
# NAME_PAYMENT_TYPE
# CODE_REJECT_REASON
# NAME_TYPE_SUITE_y
# NAME_CLIENT_TYPE
# NAME_GOODS_CATEGORY
# NAME_PORTFOLIO
# NAME_PRODUCT_TYPE
# CHANNEL_TYPE
# SELLERPLACE_AREA
# NAME_SELLER_INDUSTRY
# CNT_PAYMENT
# NAME_YIELD_GROUP
# PRODUCT_COMBINATION
# DAYS_FIRST_DRAWING
# DAYS_FIRST_DUE
# DAYS_LAST_DUE_1ST_VERSION
# DAYS_LAST_DUE
# DAYS_TERMINATION
# NFLAG_INSURED_ON_APPROVAL

# %%
df.dtypes
# Out:
# SK_ID_CURR                     int64
# TARGET                         int64
# NAME_CONTRACT_TYPE_x          object
# CODE_GENDER                   object
# FLAG_OWN_CAR                  object
#                               ...
# DAYS_FIRST_DUE               float64
# DAYS_LAST_DUE_1ST_VERSION    float64
# DAYS_LAST_DUE                float64
# DAYS_TERMINATION             float64
# NFLAG_INSURED_ON_APPROVAL    float64
# Length: 158, dtype: object

# %%
df.isnull().sum()
# Out:
# SK_ID_CURR                        0
# TARGET                            0
# NAME_CONTRACT_TYPE_x              0
# CODE_GENDER                       0
# FLAG_OWN_CAR                      0
#                               ...
# DAYS_FIRST_DUE               561106
# DAYS_LAST_DUE_1ST_VERSION    561106
# DAYS_LAST_DUE                561106
# DAYS_TERMINATION             561106
# NFLAG_INSURED_ON_APPROVAL    561106
# Length: 158, dtype: int64

# %%
df['WEEKDAY_APPR_PROCESS_START_x']
# Out:
# 0          WEDNESDAY
# 1             MONDAY
# 2             MONDAY
# 3             MONDAY
# 4             MONDAY
#              ...
# 1413696     THURSDAY
# 1413697     THURSDAY
# 1413698     THURSDAY
# 1413699     THURSDAY
# 1413700     THURSDAY
# Name: WEEKDAY_APPR_PROCESS_START_x, Length: 1413701, dtype: object

# %%
df['DAYS_LAST_PHONE_CHANGE']
# Out:
# 0         -1134.0
# 1          -828.0
# 2          -828.0
# 3          -828.0
# 4          -815.0
#             ...
# 1413696    -787.0
# 1413697    -787.0
# 1413698    -787.0
# 1413699    -787.0
# 1413700    -787.0
# Name: DAYS_LAST_PHONE_CHANGE, Length: 1413701, dtype: float64

# %%
d = df.isnull().mean() * 100


# Convert to DataFrame for better readability
d_df = d.reset_index()
d_df.columns = ['Column', 'Missing_Percentage']

pd.set_option('display.max_rows', None)

# Display the DataFrame
print(d_df)
# Out:
#                            Column  Missing_Percentage
# 0                      SK_ID_CURR            0.000000
# 1                          TARGET            0.000000
# 2            NAME_CONTRACT_TYPE_x            0.000000
# 3                     CODE_GENDER            0.000000
# 4                    FLAG_OWN_CAR            0.000000
# 5                 FLAG_OWN_REALTY            0.000000
# 6                    CNT_CHILDREN            0.000000
# 7                AMT_INCOME_TOTAL            0.000000
# 8                    AMT_CREDIT_x            0.000000
# 9                   AMT_ANNUITY_x            0.006578
# 10              AMT_GOODS_PRICE_x            0.085449
# 11              NAME_TYPE_SUITE_x            0.249416
# 12               NAME_INCOME_TYPE            0.000000
# 13            NAME_EDUCATION_TYPE            0.000000
# 14             NAME_FAMILY_STATUS            0.000000
# 15              NAME_HOUSING_TYPE            0.000000
# 16     REGION_POPULATION_RELATIVE            0.000000
# 17                     DAYS_BIRTH            0.000000
# 18                  DAYS_EMPLOYED            0.000000
# 19              DAYS_REGISTRATION            0.000000
# 20                DAYS_ID_PUBLISH            0.000000
# 21                    OWN_CAR_AGE           66.294499
# 22                     FLAG_MOBIL            0.000000
# 23                 FLAG_EMP_PHONE            0.000000
# 24                FLAG_WORK_PHONE            0.000000
# 25               FLAG_CONT_MOBILE            0.000000
# 26                     FLAG_PHONE            0.000000
# 27                     FLAG_EMAIL            0.000000
# 28                OCCUPATION_TYPE           32.367523
# 29                CNT_FAM_MEMBERS            0.000000
# 30           REGION_RATING_CLIENT            0.000000
# 31    REGION_RATING_CLIENT_W_CITY            0.000000
# 32   WEEKDAY_APPR_PROCESS_START_x            0.000000
# 33      HOUR_APPR_PROCESS_START_x            0.000000
# 34     REG_REGION_NOT_LIVE_REGION            0.000000
# 35     REG_REGION_NOT_WORK_REGION            0.000000
# 36    LIVE_REGION_NOT_WORK_REGION            0.000000
# 37         REG_CITY_NOT_LIVE_CITY            0.000000
# 38         REG_CITY_NOT_WORK_CITY            0.000000
# 39        LIVE_CITY_NOT_WORK_CITY            0.000000
# 40              ORGANIZATION_TYPE            0.000000
# 41                   EXT_SOURCE_1           56.366870
# 42                   EXT_SOURCE_2            0.128811
# 43                   EXT_SOURCE_3           17.107012
# 44                 APARTMENTS_AVG           50.364115
# 45               BASEMENTAREA_AVG           58.308511
# 46    YEARS_BEGINEXPLUATATION_AVG           48.431882
# 47                YEARS_BUILD_AVG           66.298107
# 48                 COMMONAREA_AVG           69.689347
# 49                  ELEVATORS_AVG           52.996779
# 50                  ENTRANCES_AVG           49.995155
# 51                  FLOORSMAX_AVG           49.409882
# 52                  FLOORSMIN_AVG           67.670604
# 53                   LANDAREA_AVG           59.218533
# 54           LIVINGAPARTMENTS_AVG           68.214566
# 55                 LIVINGAREA_AVG           49.826661
# 56        NONLIVINGAPARTMENTS_AVG           69.296549
# 57              NONLIVINGAREA_AVG           54.860115
# 58                APARTMENTS_MODE           50.364115
# 59              BASEMENTAREA_MODE           58.308511
# 60   YEARS_BEGINEXPLUATATION_MODE           48.431882
# 61               YEARS_BUILD_MODE           66.298107
# 62                COMMONAREA_MODE           69.689347
# 63                 ELEVATORS_MODE           52.996779
# 64                 ENTRANCES_MODE           49.995155
# 65                 FLOORSMAX_MODE           49.409882
# 66                 FLOORSMIN_MODE           67.670604
# 67                  LANDAREA_MODE           59.218533
# 68          LIVINGAPARTMENTS_MODE           68.214566
# 69                LIVINGAREA_MODE           49.826661
# 70       NONLIVINGAPARTMENTS_MODE           69.296549
# 71             NONLIVINGAREA_MODE           54.860115
# 72                APARTMENTS_MEDI           50.364115
# 73              BASEMENTAREA_MEDI           58.308511
# 74   YEARS_BEGINEXPLUATATION_MEDI           48.431882
# 75               YEARS_BUILD_MEDI           66.298107
# 76                COMMONAREA_MEDI           69.689347
# 77                 ELEVATORS_MEDI           52.996779
# 78                 ENTRANCES_MEDI           49.995155
# 79                 FLOORSMAX_MEDI           49.409882
# 80                 FLOORSMIN_MEDI           67.670604
# 81                  LANDAREA_MEDI           59.218533
# 82          LIVINGAPARTMENTS_MEDI           68.214566
# 83                LIVINGAREA_MEDI           49.826661
# 84       NONLIVINGAPARTMENTS_MEDI           69.296549
# 85             NONLIVINGAREA_MEDI           54.860115
# 86             FONDKAPREMONT_MODE           68.216264
# 87                 HOUSETYPE_MODE           49.810108
# 88                 TOTALAREA_MODE           47.926754
# 89             WALLSMATERIAL_MODE           50.462297
# 90            EMERGENCYSTATE_MODE           47.064478
# 91       OBS_30_CNT_SOCIAL_CIRCLE            0.222536
# 92       DEF_30_CNT_SOCIAL_CIRCLE            0.222536
# 93       OBS_60_CNT_SOCIAL_CIRCLE            0.222536
# 94       DEF_60_CNT_SOCIAL_CIRCLE            0.222536
# 95         DAYS_LAST_PHONE_CHANGE            0.000000
# 96                FLAG_DOCUMENT_2            0.000000
# 97                FLAG_DOCUMENT_3            0.000000
# 98                FLAG_DOCUMENT_4            0.000000
# 99                FLAG_DOCUMENT_5            0.000000
# 100               FLAG_DOCUMENT_6            0.000000
# 101               FLAG_DOCUMENT_7            0.000000
# 102               FLAG_DOCUMENT_8            0.000000
# 103               FLAG_DOCUMENT_9            0.000000
# 104              FLAG_DOCUMENT_10            0.000000
# 105              FLAG_DOCUMENT_11            0.000000
# 106              FLAG_DOCUMENT_12            0.000000
# 107              FLAG_DOCUMENT_13            0.000000
# 108              FLAG_DOCUMENT_14            0.000000
# 109              FLAG_DOCUMENT_15            0.000000
# 110              FLAG_DOCUMENT_16            0.000000
# 111              FLAG_DOCUMENT_17            0.000000
# 112              FLAG_DOCUMENT_18            0.000000
# 113              FLAG_DOCUMENT_19            0.000000
# 114              FLAG_DOCUMENT_20            0.000000
# 115              FLAG_DOCUMENT_21            0.000000
# 116    AMT_REQ_CREDIT_BUREAU_HOUR           11.574371
# 117     AMT_REQ_CREDIT_BUREAU_DAY           11.574371
# 118    AMT_REQ_CREDIT_BUREAU_WEEK           11.574371
# 119     AMT_REQ_CREDIT_BUREAU_MON           11.574371
# 120     AMT_REQ_CREDIT_BUREAU_QRT           11.574371
# 121    AMT_REQ_CREDIT_BUREAU_YEAR           11.574371
# 122                    SK_ID_PREV            0.000000
# 123          NAME_CONTRACT_TYPE_y            0.000000
# 124                 AMT_ANNUITY_y           21.731469
# 125               AMT_APPLICATION            0.000000
# 126                  AMT_CREDIT_y            0.000071
# 127              AMT_DOWN_PAYMENT           53.019698
# 128             AMT_GOODS_PRICE_y           22.602021
# 129  WEEKDAY_APPR_PROCESS_START_y            0.000000
# 130     HOUR_APPR_PROCESS_START_y            0.000000
# 131   FLAG_LAST_APPL_PER_CONTRACT            0.000000
# 132        NFLAG_LAST_APPL_IN_DAY            0.000000
# 133             RATE_DOWN_PAYMENT           53.019698
# 134         RATE_INTEREST_PRIMARY           99.661102
# 135      RATE_INTEREST_PRIVILEGED           99.661102
# 136        NAME_CASH_LOAN_PURPOSE            0.000000
# 137          NAME_CONTRACT_STATUS            0.000000
# 138                 DAYS_DECISION            0.000000
# 139             NAME_PAYMENT_TYPE            0.000000
# 140            CODE_REJECT_REASON            0.000000
# 141             NAME_TYPE_SUITE_y           49.138538
# 142              NAME_CLIENT_TYPE            0.000000
# 143           NAME_GOODS_CATEGORY            0.000000
# 144                NAME_PORTFOLIO            0.000000
# 145             NAME_PRODUCT_TYPE            0.000000
# 146                  CHANNEL_TYPE            0.000000
# 147              SELLERPLACE_AREA            0.000000
# 148          NAME_SELLER_INDUSTRY            0.000000
# 149                   CNT_PAYMENT           21.731116
# 150              NAME_YIELD_GROUP            0.000000
# 151           PRODUCT_COMBINATION            0.022140
# 152            DAYS_FIRST_DRAWING           39.690571
# 153                DAYS_FIRST_DUE           39.690571
# 154     DAYS_LAST_DUE_1ST_VERSION           39.690571
# 155                 DAYS_LAST_DUE           39.690571
# 156              DAYS_TERMINATION           39.690571
# 157     NFLAG_INSURED_ON_APPROVAL           39.690571

# %%
d.sort_values(ascending=False).reset_index().iloc[0:60]
# Out:
#                            index          0
# 0       RATE_INTEREST_PRIVILEGED  99.661102
# 1          RATE_INTEREST_PRIMARY  99.661102
# 2                COMMONAREA_MODE  69.689347
# 3                COMMONAREA_MEDI  69.689347
# 4                 COMMONAREA_AVG  69.689347
# 5       NONLIVINGAPARTMENTS_MEDI  69.296549
# 6        NONLIVINGAPARTMENTS_AVG  69.296549
# 7       NONLIVINGAPARTMENTS_MODE  69.296549
# 8             FONDKAPREMONT_MODE  68.216264
# 9          LIVINGAPARTMENTS_MODE  68.214566
# 10          LIVINGAPARTMENTS_AVG  68.214566
# 11         LIVINGAPARTMENTS_MEDI  68.214566
# 12                FLOORSMIN_MEDI  67.670604
# 13                 FLOORSMIN_AVG  67.670604
# 14                FLOORSMIN_MODE  67.670604
# 15              YEARS_BUILD_MEDI  66.298107
# 16               YEARS_BUILD_AVG  66.298107
# 17              YEARS_BUILD_MODE  66.298107
# 18                   OWN_CAR_AGE  66.294499
# 19                 LANDAREA_MEDI  59.218533
# 20                 LANDAREA_MODE  59.218533
# 21                  LANDAREA_AVG  59.218533
# 22              BASEMENTAREA_AVG  58.308511
# 23             BASEMENTAREA_MODE  58.308511
# 24             BASEMENTAREA_MEDI  58.308511
# 25                  EXT_SOURCE_1  56.366870
# 26            NONLIVINGAREA_MEDI  54.860115
# 27            NONLIVINGAREA_MODE  54.860115
# 28             NONLIVINGAREA_AVG  54.860115
# 29              AMT_DOWN_PAYMENT  53.019698
# 30             RATE_DOWN_PAYMENT  53.019698
# 31                ELEVATORS_MEDI  52.996779
# 32                 ELEVATORS_AVG  52.996779
# 33                ELEVATORS_MODE  52.996779
# 34            WALLSMATERIAL_MODE  50.462297
# 35                APARTMENTS_AVG  50.364115
# 36               APARTMENTS_MODE  50.364115
# 37               APARTMENTS_MEDI  50.364115
# 38                ENTRANCES_MODE  49.995155
# 39                ENTRANCES_MEDI  49.995155
# 40                 ENTRANCES_AVG  49.995155
# 41               LIVINGAREA_MODE  49.826661
# 42                LIVINGAREA_AVG  49.826661
# 43               LIVINGAREA_MEDI  49.826661
# 44                HOUSETYPE_MODE  49.810108
# 45                FLOORSMAX_MODE  49.409882
# 46                 FLOORSMAX_AVG  49.409882
# 47                FLOORSMAX_MEDI  49.409882
# 48             NAME_TYPE_SUITE_y  49.138538
# 49   YEARS_BEGINEXPLUATATION_AVG  48.431882
# 50  YEARS_BEGINEXPLUATATION_MODE  48.431882
# 51  YEARS_BEGINEXPLUATATION_MEDI  48.431882
# 52                TOTALAREA_MODE  47.926754
# 53           EMERGENCYSTATE_MODE  47.064478
# 54            DAYS_FIRST_DRAWING  39.690571
# 55                DAYS_FIRST_DUE  39.690571
# 56     DAYS_LAST_DUE_1ST_VERSION  39.690571
# 57                 DAYS_LAST_DUE  39.690571
# 58              DAYS_TERMINATION  39.690571
# 59     NFLAG_INSURED_ON_APPROVAL  39.690571

# %%
df1 =df.copy()

# %%
df1.shape
# Out:
# (1413701, 158)

# %% [markdown]
# The features listed are relevant because they provide comprehensive information about the applicants, their financial status, and their behavior, which are crucial for assessing credit risk.

# %%
relevant_features = [
    'TARGET',
'CODE_GENDER',
'DAYS_BIRTH',
'FLAG_OWN_CAR',
'FLAG_OWN_REALTY',
'CNT_CHILDREN',
'AMT_INCOME_TOTAL',
'AMT_CREDIT_x',
'AMT_ANNUITY_x',
'AMT_GOODS_PRICE_x',
'NAME_INCOME_TYPE',
'NAME_EDUCATION_TYPE',
'NAME_FAMILY_STATUS',
'NAME_HOUSING_TYPE',
'DAYS_EMPLOYED',
'OCCUPATION_TYPE',
'CNT_FAM_MEMBERS',
'REGION_RATING_CLIENT',
'EXT_SOURCE_1',
'EXT_SOURCE_2',
'EXT_SOURCE_3',
'DAYS_REGISTRATION',
'DAYS_ID_PUBLISH',
'FLAG_MOBIL',
'FLAG_WORK_PHONE',
'FLAG_PHONE',
'FLAG_EMAIL',
'DAYS_LAST_PHONE_CHANGE',
'WEEKDAY_APPR_PROCESS_START_x',
'HOUR_APPR_PROCESS_START_x',
'REG_CITY_NOT_LIVE_CITY',
'REG_CITY_NOT_WORK_CITY',
'LIVE_CITY_NOT_WORK_CITY',
'NAME_CONTRACT_TYPE_x',
'ORGANIZATION_TYPE',
'AMT_REQ_CREDIT_BUREAU_YEAR',
'AMT_REQ_CREDIT_BUREAU_MON',
'OBS_30_CNT_SOCIAL_CIRCLE',
'DEF_30_CNT_SOCIAL_CIRCLE',
'NAME_CONTRACT_STATUS'
]

# %%
len(relevant_features)
# Out:
# 40

# %%
df11 =df1[relevant_features]

# %%
df11.columns
# Out:
# Index(['TARGET', 'CODE_GENDER', 'DAYS_BIRTH', 'FLAG_OWN_CAR',
#        'FLAG_OWN_REALTY', 'CNT_CHILDREN', 'AMT_INCOME_TOTAL', 'AMT_CREDIT_x',
#        'AMT_ANNUITY_x', 'AMT_GOODS_PRICE_x', 'NAME_INCOME_TYPE',
#        'NAME_EDUCATION_TYPE', 'NAME_FAMILY_STATUS', 'NAME_HOUSING_TYPE',
#        'DAYS_EMPLOYED', 'OCCUPATION_TYPE', 'CNT_FAM_MEMBERS',
#        'REGION_RATING_CLIENT', 'EXT_SOURCE_1', 'EXT_SOURCE_2', 'EXT_SOURCE_3',
#        'DAYS_REGISTRATION', 'DAYS_ID_PUBLISH', 'FLAG_MOBIL', 'FLAG_WORK_PHONE',
#        'FLAG_PHONE', 'FLAG_EMAIL', 'DAYS_LAST_PHONE_CHANGE',
#        'WEEKDAY_APPR_PROCESS_START_x', 'HOUR_APPR_PROCESS_START_x',
#        'REG_CITY_NOT_LIVE_CITY', 'REG_CITY_NOT_WORK_CITY',
#        'LIVE_CITY_NOT_WORK_CITY', 'NAME_CONTRACT_TYPE_x', 'ORGANIZATION_TYPE',
#        'AMT_REQ_CREDIT_BUREAU_YEAR', 'AMT_REQ_CREDIT_BUREAU_MON',
#        'OBS_30_CNT_SOCIAL_CIRCLE', 'DEF_30_CNT_SOCIAL_CIRCLE',
#        'NAME_CONTRACT_STATUS'],
#       dtype='object')

# %% [markdown]
# Also These columns provide a balanced view of demographic, financial, employment, and behavioral information, which are essential for assessing credit risk and making informed lending decisions.

# %%
df11.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1413701 entries, 0 to 1413700
# Data columns (total 40 columns):
#  #   Column                        Non-Null Count    Dtype
# ---  ------                        --------------    -----
#  0   TARGET                        1413701 non-null  int64
#  1   CODE_GENDER                   1413701 non-null  object
#  2   DAYS_BIRTH                    1413701 non-null  int64
#  3   FLAG_OWN_CAR                  1413701 non-null  object
#  4   FLAG_OWN_REALTY               1413701 non-null  object
#  5   CNT_CHILDREN                  1413701 non-null  int64
#  6   AMT_INCOME_TOTAL              1413701 non-null  float64
#  7   AMT_CREDIT_x                  1413701 non-null  float64
#  8   AMT_ANNUITY_x                 1413608 non-null  float64
#  9   AMT_GOODS_PRICE_x             1412493 non-null  float64
#  10  NAME_INCOME_TYPE              1413701 non-null  object
#  11  NAME_EDUCATION_TYPE           1413701 non-null  object
#  12  NAME_FAMILY_STATUS            1413701 non-null  object
#  13  NAME_HOUSING_TYPE             1413701 non-null  object
#  14  DAYS_EMPLOYED                 1413701 non-null  int64
#  15  OCCUPATION_TYPE               956121 non-null   object
#  16  CNT_FAM_MEMBERS               1413701 non-null  float64
#  17  REGION_RATING_CLIENT          1413701 non-null  int64
#  18  EXT_SOURCE_1                  616842 non-null   float64
#  19  EXT_SOURCE_2                  1411880 non-null  float64
#  20  EXT_SOURCE_3                  1171859 non-null  float64
#  21  DAYS_REGISTRATION             1413701 non-null  float64
#  22  DAYS_ID_PUBLISH               1413701 non-null  int64
#  23  FLAG_MOBIL                    1413701 non-null  int64
#  24  FLAG_WORK_PHONE               1413701 non-null  int64
#  25  FLAG_PHONE                    1413701 non-null  int64
#  26  FLAG_EMAIL                    1413701 non-null  int64
#  27  DAYS_LAST_PHONE_CHANGE        1413701 non-null  float64
#  28  WEEKDAY_APPR_PROCESS_START_x  1413701 non-null  object
#  29  HOUR_APPR_PROCESS_START_x     1413701 non-null  int64
#  30  REG_CITY_NOT_LIVE_CITY        1413701 non-null  int64
#  31  REG_CITY_NOT_WORK_CITY        1413701 non-null  int64
#  32  LIVE_CITY_NOT_WORK_CITY       1413701 non-null  int64
#  33  NAME_CONTRACT_TYPE_x          1413701 non-null  object
#  34  ORGANIZATION_TYPE             1413701 non-null  object
#  35  AMT_REQ_CREDIT_BUREAU_YEAR    1250074 non-null  float64
#  36  AMT_REQ_CREDIT_BUREAU_MON     1250074 non-null  float64
#  37  OBS_30_CNT_SOCIAL_CIRCLE      1410555 non-null  float64
#  38  DEF_30_CNT_SOCIAL_CIRCLE      1410555 non-null  float64
#  39  NAME_CONTRACT_STATUS          1413701 non-null  object
# dtypes: float64(14), int64(14), object(12)
# memory usage: 431.4+ MB

# %%
df11.isnull().mean().sort_values(ascending=False).head(5)
# Out:
# EXT_SOURCE_1                  0.563669
# OCCUPATION_TYPE               0.323675
# EXT_SOURCE_3                  0.171070
# AMT_REQ_CREDIT_BUREAU_MON     0.115744
# AMT_REQ_CREDIT_BUREAU_YEAR    0.115744
# dtype: float64

# %%
df11['EXT_SOURCE_1'].head(5)
# Out:
# 0    0.083037
# 1    0.311267
# 2    0.311267
# 3    0.311267
# 4         NaN
# Name: EXT_SOURCE_1, dtype: float64

# %%
df11['EXT_SOURCE_2'].head(15)
# Out:
# 0     0.262949
# 1     0.622246
# 2     0.622246
# 3     0.622246
# 4     0.555912
# 5     0.650442
# 6     0.650442
# 7     0.650442
# 8     0.650442
# 9     0.650442
# 10    0.650442
# 11    0.650442
# 12    0.650442
# 13    0.650442
# 14    0.322738
# Name: EXT_SOURCE_2, dtype: float64

# %%
#Dropping EXT_SOURCE_1 & EXT_SOURCE_2 as it may correlate with other similar columns

df11.drop(columns=['EXT_SOURCE_1','EXT_SOURCE_2'],inplace=True)

# %%
df11['EXT_SOURCE_3'].fillna(df11['EXT_SOURCE_3'].median(),inplace=True)

# %%
df11['OCCUPATION_TYPE'].unique()
# Out:
# array(['Laborers', 'Core staff', 'Accountants', 'Managers', nan,
#        'Drivers', 'Sales staff', 'Cleaning staff',
#        'Private service staff', 'Medicine staff', 'Security staff',
#        'Cooking staff', 'High skill tech staff', 'Waiters/barmen staff',
#        'Low-skill Laborers', 'Realty agents', 'Secretaries', 'IT staff',
#        'HR staff'], dtype=object)

# %%
#Dropping NA values from Occupation Type

df11.dropna(subset=["OCCUPATION_TYPE"], inplace=True)  # drop null columns

# %%
df11.isnull().mean().sort_values(ascending=False).head(5)*100
# Out:
# AMT_REQ_CREDIT_BUREAU_MON     11.492792
# AMT_REQ_CREDIT_BUREAU_YEAR    11.492792
# DEF_30_CNT_SOCIAL_CIRCLE       0.219951
# OBS_30_CNT_SOCIAL_CIRCLE       0.219951
# AMT_GOODS_PRICE_x              0.098000
# dtype: float64

# %%
df11.isnull().mean()
# Out:
# TARGET                          0.000000
# CODE_GENDER                     0.000000
# DAYS_BIRTH                      0.000000
# FLAG_OWN_CAR                    0.000000
# FLAG_OWN_REALTY                 0.000000
# CNT_CHILDREN                    0.000000
# AMT_INCOME_TOTAL                0.000000
# AMT_CREDIT_x                    0.000000
# AMT_ANNUITY_x                   0.000097
# AMT_GOODS_PRICE_x               0.000980
# NAME_INCOME_TYPE                0.000000
# NAME_EDUCATION_TYPE             0.000000
# NAME_FAMILY_STATUS              0.000000
# NAME_HOUSING_TYPE               0.000000
# DAYS_EMPLOYED                   0.000000
# OCCUPATION_TYPE                 0.000000
# CNT_FAM_MEMBERS                 0.000000
# REGION_RATING_CLIENT            0.000000
# EXT_SOURCE_3                    0.000000
# DAYS_REGISTRATION               0.000000
# DAYS_ID_PUBLISH                 0.000000
# FLAG_MOBIL                      0.000000
# FLAG_WORK_PHONE                 0.000000
# FLAG_PHONE                      0.000000
# FLAG_EMAIL                      0.000000
# DAYS_LAST_PHONE_CHANGE          0.000000
# WEEKDAY_APPR_PROCESS_START_x    0.000000
# HOUR_APPR_PROCESS_START_x       0.000000
# REG_CITY_NOT_LIVE_CITY          0.000000
# REG_CITY_NOT_WORK_CITY          0.000000
# LIVE_CITY_NOT_WORK_CITY         0.000000
# NAME_CONTRACT_TYPE_x            0.000000
# ORGANIZATION_TYPE               0.000000
# AMT_REQ_CREDIT_BUREAU_YEAR      0.114928
# AMT_REQ_CREDIT_BUREAU_MON       0.114928
# OBS_30_CNT_SOCIAL_CIRCLE        0.002200
# DEF_30_CNT_SOCIAL_CIRCLE        0.002200
# NAME_CONTRACT_STATUS            0.000000
# dtype: float64

# %%
df11.columns
# Out:
# Index(['TARGET', 'CODE_GENDER', 'DAYS_BIRTH', 'FLAG_OWN_CAR',
#        'FLAG_OWN_REALTY', 'CNT_CHILDREN', 'AMT_INCOME_TOTAL', 'AMT_CREDIT_x',
#        'AMT_ANNUITY_x', 'AMT_GOODS_PRICE_x', 'NAME_INCOME_TYPE',
#        'NAME_EDUCATION_TYPE', 'NAME_FAMILY_STATUS', 'NAME_HOUSING_TYPE',
#        'DAYS_EMPLOYED', 'OCCUPATION_TYPE', 'CNT_FAM_MEMBERS',
#        'REGION_RATING_CLIENT', 'EXT_SOURCE_3', 'DAYS_REGISTRATION',
#        'DAYS_ID_PUBLISH', 'FLAG_MOBIL', 'FLAG_WORK_PHONE', 'FLAG_PHONE',
#        'FLAG_EMAIL', 'DAYS_LAST_PHONE_CHANGE', 'WEEKDAY_APPR_PROCESS_START_x',
#        'HOUR_APPR_PROCESS_START_x', 'REG_CITY_NOT_LIVE_CITY',
#        'REG_CITY_NOT_WORK_CITY', 'LIVE_CITY_NOT_WORK_CITY',
#        'NAME_CONTRACT_TYPE_x', 'ORGANIZATION_TYPE',
#        'AMT_REQ_CREDIT_BUREAU_YEAR', 'AMT_REQ_CREDIT_BUREAU_MON',
#        'OBS_30_CNT_SOCIAL_CIRCLE', 'DEF_30_CNT_SOCIAL_CIRCLE',
#        'NAME_CONTRACT_STATUS'],
#       dtype='object')

# %%
df11.shape
# Out:
# (956121, 38)

# %%
df11["TARGET"].value_counts()
# Out:
# TARGET
# 0    865635
# 1     90486
# Name: count, dtype: int64

# %%
#Extracting this filtered data into separate csv file

df11.to_csv('cleaned_data.csv',index=False)

# %%
df2 = pd.read_csv('cleaned_data.csv')

# %%
df2.head(20)
# Out:
#     TARGET CODE_GENDER  DAYS_BIRTH FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0        1           M       -9461            N               Y             0
# 1        0           F      -16765            N               N             0
# 2        0           F      -16765            N               N             0
# 3        0           F      -16765            N               N             0
# 4        0           M      -19046            Y               Y             0
# 5        0           F      -19005            N               Y             0
# 6        0           F      -19005            N               Y             0
# 7        0           F      -19005            N               Y             0
# 8        0           F      -19005            N               Y             0
# 9        0           F      -19005            N               Y             0
# 10       0           F      -19005            N               Y             0
# 11       0           F      -19005            N               Y             0
# 12       0           F      -19005            N               Y             0
# 13       0           F      -19005            N               Y             0
# 14       0           M      -19932            N               Y             0
# 15       0           M      -19932            N               Y             0
# 16       0           M      -19932            N               Y             0
# 17       0           M      -19932            N               Y             0
# 18       0           M      -19932            N               Y             0
# 19       0           M      -19932            N               Y             0
#
#     AMT_INCOME_TOTAL  AMT_CREDIT_x  AMT_ANNUITY_x  AMT_GOODS_PRICE_x  ...  \
# 0           202500.0      406597.5        24700.5           351000.0  ...
# 1           270000.0     1293502.5        35698.5          1129500.0  ...
# 2           270000.0     1293502.5        35698.5          1129500.0  ...
# 3           270000.0     1293502.5        35698.5          1129500.0  ...
# 4            67500.0      135000.0         6750.0           135000.0  ...
# 5           135000.0      312682.5        29686.5           297000.0  ...
# 6           135000.0      312682.5        29686.5           297000.0  ...
# 7           135000.0      312682.5        29686.5           297000.0  ...
# 8           135000.0      312682.5        29686.5           297000.0  ...
# 9           135000.0      312682.5        29686.5           297000.0  ...
# 10          135000.0      312682.5        29686.5           297000.0  ...
# 11          135000.0      312682.5        29686.5           297000.0  ...
# 12          135000.0      312682.5        29686.5           297000.0  ...
# 13          135000.0      312682.5        29686.5           297000.0  ...
# 14          121500.0      513000.0        21865.5           513000.0  ...
# 15          121500.0      513000.0        21865.5           513000.0  ...
# 16          121500.0      513000.0        21865.5           513000.0  ...
# 17          121500.0      513000.0        21865.5           513000.0  ...
# 18          121500.0      513000.0        21865.5           513000.0  ...
# 19          121500.0      513000.0        21865.5           513000.0  ...
#
#    REG_CITY_NOT_LIVE_CITY REG_CITY_NOT_WORK_CITY LIVE_CITY_NOT_WORK_CITY  \
# 0                       0                      0                       0
# 1                       0                      0                       0
# 2                       0                      0                       0
# 3                       0                      0                       0
# 4                       0                      0                       0
# 5                       0                      0                       0
# 6                       0                      0                       0
# 7                       0                      0                       0
# 8                       0                      0                       0
# 9                       0                      0                       0
# 10                      0                      0                       0
# 11                      0                      0                       0
# 12                      0                      0                       0
# 13                      0                      0                       0
# 14                      0                      1                       1
# 15                      0                      1                       1
# 16                      0                      1                       1
# 17                      0                      1                       1
# 18                      0                      1                       1
# 19                      0                      1                       1
#
#    NAME_CONTRACT_TYPE_x       ORGANIZATION_TYPE AMT_REQ_CREDIT_BUREAU_YEAR  \
# 0            Cash loans  Business Entity Type 3                        1.0
# 1            Cash loans                  School                        0.0
# 2            Cash loans                  School                        0.0
# 3            Cash loans                  School                        0.0
# 4       Revolving loans              Government                        0.0
# 5            Cash loans  Business Entity Type 3                        NaN
# 6            Cash loans  Business Entity Type 3                        NaN
# 7            Cash loans  Business Entity Type 3                        NaN
# 8            Cash loans  Business Entity Type 3                        NaN
# 9            Cash loans  Business Entity Type 3                        NaN
# 10           Cash loans  Business Entity Type 3                        NaN
# 11           Cash loans  Business Entity Type 3                        NaN
# 12           Cash loans  Business Entity Type 3                        NaN
# 13           Cash loans  Business Entity Type 3                        NaN
# 14           Cash loans                Religion                        0.0
# 15           Cash loans                Religion                        0.0
# 16           Cash loans                Religion                        0.0
# 17           Cash loans                Religion                        0.0
# 18           Cash loans                Religion                        0.0
# 19           Cash loans                Religion                        0.0
#
#     AMT_REQ_CREDIT_BUREAU_MON  OBS_30_CNT_SOCIAL_CIRCLE  \
# 0                         0.0                       2.0
# 1                         0.0                       1.0
# 2                         0.0                       1.0
# 3                         0.0                       1.0
# 4                         0.0                       0.0
# 5                         NaN                       2.0
# 6                         NaN                       2.0
# 7                         NaN                       2.0
# 8                         NaN                       2.0
# 9                         NaN                       2.0
# 10                        NaN                       2.0
# 11                        NaN                       2.0
# 12                        NaN                       2.0
# 13                        NaN                       2.0
# 14                        0.0                       0.0
# 15                        0.0                       0.0
# 16                        0.0                       0.0
# 17                        0.0                       0.0
# 18                        0.0                       0.0
# 19                        0.0                       0.0
#
#     DEF_30_CNT_SOCIAL_CIRCLE  NAME_CONTRACT_STATUS
# 0                        2.0              Approved
# 1                        0.0              Approved
# 2                        0.0              Approved
# 3                        0.0              Approved
# 4                        0.0              Approved
# 5                        0.0              Approved
# 6                        0.0              Canceled
# 7                        0.0              Approved
# 8                        0.0              Approved
# 9                        0.0              Approved
# 10                       0.0              Canceled
# 11                       0.0              Approved
# 12                       0.0              Canceled
# 13                       0.0               Refused
# 14                       0.0              Approved
# 15                       0.0              Approved
# 16                       0.0              Approved
# 17                       0.0              Approved
# 18                       0.0              Approved
# 19                       0.0              Approved
#
# [20 rows x 38 columns]

# %%
df2[df2['TARGET']==1].head(10)
# Out:
#      TARGET CODE_GENDER  DAYS_BIRTH FLAG_OWN_CAR FLAG_OWN_REALTY  \
# 0         1           M       -9461            N               Y
# 125       1           M      -17482            N               Y
# 126       1           M      -17482            N               Y
# 127       1           M      -17482            N               Y
# 128       1           M      -17482            N               Y
# 129       1           M      -17482            N               Y
# 130       1           M      -17482            N               Y
# 135       1           F      -13384            N               N
# 136       1           F      -13384            N               N
# 137       1           F      -13384            N               N
#
#      CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT_x  AMT_ANNUITY_x  \
# 0               0          202500.0      406597.5        24700.5
# 125             0          202500.0     1193580.0        35028.0
# 126             0          202500.0     1193580.0        35028.0
# 127             0          202500.0     1193580.0        35028.0
# 128             0          202500.0     1193580.0        35028.0
# 129             0          202500.0     1193580.0        35028.0
# 130             0          202500.0     1193580.0        35028.0
# 135             0          135000.0      288873.0        16258.5
# 136             0          135000.0      288873.0        16258.5
# 137             0          135000.0      288873.0        16258.5
#
#      AMT_GOODS_PRICE_x  ... REG_CITY_NOT_LIVE_CITY REG_CITY_NOT_WORK_CITY  \
# 0             351000.0  ...                      0                      0
# 125           855000.0  ...                      0                      0
# 126           855000.0  ...                      0                      0
# 127           855000.0  ...                      0                      0
# 128           855000.0  ...                      0                      0
# 129           855000.0  ...                      0                      0
# 130           855000.0  ...                      0                      0
# 135           238500.0  ...                      0                      0
# 136           238500.0  ...                      0                      0
# 137           238500.0  ...                      0                      0
#
#     LIVE_CITY_NOT_WORK_CITY NAME_CONTRACT_TYPE_x       ORGANIZATION_TYPE  \
# 0                         0           Cash loans  Business Entity Type 3
# 125                       0           Cash loans  Business Entity Type 3
# 126                       0           Cash loans  Business Entity Type 3
# 127                       0           Cash loans  Business Entity Type 3
# 128                       0           Cash loans  Business Entity Type 3
# 129                       0           Cash loans  Business Entity Type 3
# 130                       0           Cash loans  Business Entity Type 3
# 135                       0           Cash loans           Self-employed
# 136                       0           Cash loans           Self-employed
# 137                       0           Cash loans           Self-employed
#
#     AMT_REQ_CREDIT_BUREAU_YEAR  AMT_REQ_CREDIT_BUREAU_MON  \
# 0                          1.0                        0.0
# 125                        4.0                        2.0
# 126                        4.0                        2.0
# 127                        4.0                        2.0
# 128                        4.0                        2.0
# 129                        4.0                        2.0
# 130                        4.0                        2.0
# 135                        2.0                        0.0
# 136                        2.0                        0.0
# 137                        2.0                        0.0
#
#      OBS_30_CNT_SOCIAL_CIRCLE  DEF_30_CNT_SOCIAL_CIRCLE  NAME_CONTRACT_STATUS
# 0                         2.0                       2.0              Approved
# 125                       0.0                       0.0              Approved
# 126                       0.0                       0.0              Approved
# 127                       0.0                       0.0               Refused
# 128                       0.0                       0.0              Approved
# 129                       0.0                       0.0              Approved
# 130                       0.0                       0.0               Refused
# 135                       1.0                       0.0              Approved
# 136                       1.0                       0.0              Approved
# 137                       1.0                       0.0              Approved
#
# [10 rows x 38 columns]

# %%
df2[df2['TARGET']==1]['OCCUPATION_TYPE'].value_counts()
# Out:
# OCCUPATION_TYPE
# Laborers                 28158
# Sales staff              15088
# Drivers                  10125
# Core staff                8099
# Managers                  6770
# Security staff            3709
# High skill tech staff     3384
# Cooking staff             3141
# Medicine staff            3019
# Accountants               2408
# Cleaning staff            2250
# Low-skill Laborers        1780
# Private service staff      782
# Waiters/barmen staff       669
# Secretaries                460
# Realty agents              357
# HR staff                   170
# IT staff                   117
# Name: count, dtype: int64

# %%
df2['DAYS_BIRTH'].unique()
# Out:
# array([ -9461, -16765, -19046, ..., -23072, -21682, -24319], dtype=int64)

# %%
df2['NAME_EDUCATION_TYPE'].unique()
# Out:
# array(['Secondary / secondary special', 'Higher education',
#        'Incomplete higher', 'Lower secondary', 'Academic degree'],
#       dtype=object)

# %%
#Encoding categorical variable

df2["NAME_EDUCATION_TYPE"]= df2["NAME_EDUCATION_TYPE"].map({'Secondary / secondary special':0, 'Higher education':1, 'Incomplete higher':2, 'Lower secondary':3, 'Academic degree':4})

# %%
df2['NAME_EDUCATION_TYPE'].unique()
# Out:
# array([0, 1, 2, 3, 4], dtype=int64)

# %%
df2['OCCUPATION_TYPE'].unique()
# Out:
# array(['Laborers', 'Core staff', 'Accountants', 'Managers', 'Drivers',
#        'Sales staff', 'Cleaning staff', 'Private service staff',
#        'Medicine staff', 'Security staff', 'Cooking staff',
#        'High skill tech staff', 'Waiters/barmen staff',
#        'Low-skill Laborers', 'Realty agents', 'Secretaries', 'IT staff',
#        'HR staff'], dtype=object)

# %%
df2["OCCUPATION_TYPE"]= OrdinalEncoder().fit_transform(df2[["OCCUPATION_TYPE"]])

# %%
df2["OCCUPATION_TYPE"] = df2["OCCUPATION_TYPE"].astype(int)
df2["OCCUPATION_TYPE"].unique()
# Out:
# array([ 8,  3,  0, 10,  4, 14,  1, 12, 11, 16,  2,  6, 17,  9, 13, 15,  7,
#         5])

# %%
df2['ORGANIZATION_TYPE'].unique()
# Out:
# array(['Business Entity Type 3', 'School', 'Government', 'Religion',
#        'Other', 'Electricity', 'Medicine', 'Business Entity Type 2',
#        'Self-employed', 'Transport: type 2', 'Construction', 'Housing',
#        'Kindergarten', 'Trade: type 7', 'Industry: type 11', 'Services',
#        'Security Ministries', 'Transport: type 4', 'Industry: type 1',
#        'Security', 'Trade: type 2', 'Police', 'Business Entity Type 1',
#        'Postal', 'Transport: type 3', 'Agriculture', 'Restaurant',
#        'Culture', 'Industry: type 3', 'Hotel', 'Military',
#        'Trade: type 3', 'Industry: type 9', 'Bank', 'Trade: type 6',
#        'Industry: type 2', 'University', 'Transport: type 1',
#        'Industry: type 12', 'Industry: type 4', 'Insurance',
#        'Industry: type 7', 'Emergency', 'Mobile', 'Trade: type 1',
#        'Industry: type 5', 'Industry: type 10', 'Legal Services',
#        'Advertising', 'Trade: type 5', 'Cleaning', 'Industry: type 13',
#        'Trade: type 4', 'Telecom', 'Industry: type 8', 'Realtor',
#        'Industry: type 6', 'XNA'], dtype=object)

# %%
df2["ORGANIZATION_TYPE"]= OrdinalEncoder().fit_transform(df2[["ORGANIZATION_TYPE"]])

# %%
df2["ORGANIZATION_TYPE"] = df2["ORGANIZATION_TYPE"].astype(int)
df2["ORGANIZATION_TYPE"].unique()
# Out:
# array([ 5, 39, 11, 37, 33,  9, 30,  4, 42, 53,  7, 13, 28, 51, 16, 43, 41,
#        55, 14, 40, 46, 34,  3, 35, 54,  1, 38,  8, 20, 12, 31, 47, 26,  2,
#        50, 19, 56, 52, 17, 21, 27, 24, 10, 32, 45, 22, 15, 29,  0, 49,  6,
#        18, 48, 44, 25, 36, 23, 57])

# %%
df2['NAME_CONTRACT_TYPE_x'].unique()
# Out:
# array(['Cash loans', 'Revolving loans'], dtype=object)

# %%
df2['AMT_GOODS_PRICE_x'].unique()
# Out:
# array([ 351000. , 1129500. ,  135000. ,  297000. ,  513000. ,  454500. ,
#        1395000. , 1530000. ,  405000. ,  652500. ,   67500. ,  697500. ,
#         679500. ,  247500. ,  387000. ,  270000. ,  157500. ,  927000. ,
#         450000. ,  225000. ,  180000. ,  360000. , 1125000. ,  553500. ,
#         540000. ,  855000. ,  238500. , 1350000. ,  675000. ,  666000. ,
#         517500. , 1588500. , 1080000. ,  900000. , 1035000. ,  463500. ,
#         459000. ,  256500. ,  585000. ,  643500. ,  283500. ,  472500. ,
#         337500. ,  720000. , 1089000. ,  319500. , 1435500. ,  468000. ,
#         535500. ,  198000. ,  445500. ,  144000. ,  166500. ,  967500. ,
#         945000. ,  477000. , 1354500. ,  306000. ,  189000. ,  315000. ,
#         531000. ,  252000. ,  765000. , 2250000. ,  909000. , 1102500. ,
#         787500. ,   90000. ,  427500. ,   81000. ,  522000. , 1575000. ,
#         369000. , 1710000. , 1305000. ,  747000. ,  292500. , 1201500. ,
#         202500. ,  324000. ,  148500. ,  495000. ,  630000. , 1138500. ,
#        1800000. ,  810000. , 1143000. , 1008000. , 1237500. ,  904500. ,
#        1039500. ,  103500. ,  688500. ,  877500. ,  562500. ,  139500. ,
#         693000. ,  328500. ,  634500. ,  922500. ,  229500. ,  382500. ,
#         936000. ,  130500. ,  508500. , 1183500. , 2182500. , 1053000. ,
#         778500. ,  441000. ,  400500. ,  243000. ,  504000. ,  279000. ,
#         828000. ,  760500. ,   45000. ,  112500. ,  805500. , 1017000. ,
#         963000. ,  333000. , 1098000. ,   94500. ,       nan,  990000. ,
#         607500. ,  184500. , 1030500. , 1323000. ,  481500. , 1260000. ,
#         436500. ,  832500. ,  576000. ,  621000. ,  544500. , 1003500. ,
#         841500. , 1215000. ,  567000. ,  958500. ,  859500. ,  193500. ,
#         684000. ,  702000. , 1165500. ,  603000. , 1485000. ,  931500. ,
#         670500. ,  171000. ,  549000. ,  153000. , 1467000. ,  729000. ,
#        1057500. ,  288000. ,  342000. ,  742500. ,  751500. ,  918000. ,
#         738000. ,  486000. ,  355500. ,  373500. ,  310500. ,  823500. ,
#        1206000. ,  972000. , 1012500. ,  234000. ,  661500. , 2254500. ,
#         301500. ,  274500. , 1170000. , 1156500. , 1755000. ,  126000. ,
#        1093500. ,  657000. ,  814500. ,  121500. ,  364500. ,  940500. ,
#        1579500. , 1116000. , 1453500. ,  265500. , 1696500. , 1656000. ,
#         378000. ,  526500. ,  558000. , 1341000. ,  850500. ,  706500. ,
#         598500. ,  724500. ,  594000. ,  162000. ,  418500. ,  412227. ,
#         846000. , 1269000. , 1705500. ,  715500. ,  589500. ,   99000. ,
#         873000. ,  886500. ,  580500. ,  733500. ,   58500. ,  913500. ,
#         837000. , 1282500. , 2160000. ,  117000. , 1107000. , 1287000. ,
#         801000. , 1665000. , 1539000. ,  864000. ,  423000. ,  381411. ,
#         949500. ,   54000. ,   76500. , 1192500. ,  432000. , 1372500. ,
#         868500. , 1381500. ,  391009.5, 1075500. ,  207000. ,  796500. ,
#        1152000. ,  774000. ,  571500. ,  976500. ,  409500. ,  985500. ,
#        1440000. ,  616500. , 1147500. ,  211500. , 1026000. ,  414000. ,
#         391500. ,  490500. ,  220500. ,  639000. , 1498500. , 1359000. ,
#        2245500. , 1377000. , 1642500. , 1228500. ,  954000. , 1845000. ,
#        1327500. , 1620000. ,  175500. ,  999000. ,  792000. , 1066500. ,
#         981000. ,  216000. ,  108000. ,  612000. , 2236500. ,  396000. ,
#        1161000. , 1062000. ,  492547.5, 1570500. ,   63000. , 1363500. ,
#        1417500. ,  769500. ,  625500. ,  895500. ,   85500. , 1120500. ,
#        1561500. ,  648000. ,  994500. , 1296000. , 2205000. ,  840258. ,
#        1476000. , 1318500. , 1552500. , 1314000. , 1048500. ,  261000. ,
#         891000. , 1242000. , 1084500. , 1111500. ,  882000. , 1174500. ,
#         463279.5, 1368000. ,  346500. ,   72000. ,  783000. , 1606500. ,
#         763762.5, 1264500. , 1413000. ,  494496. , 1345500. ,  711000. ,
#        1548000. , 1512000. , 1723500. , 1233000. , 1134000. ,   49500. ,
#        1273500. ,  819000. , 1291500. ,  499500. , 1822500. , 1197000. ,
#        1309500. ,  508900.5, 2961000. , 1071000. , 1813500. , 1458000. ,
#         574002. , 1602000. , 1332000. , 2002500. , 1191595.5,  146578.5,
#         430672.5, 1489500. , 1210500. , 2025000. , 1390500. , 1336500. ,
#        1611000. ,  426042. , 1768500. , 1584000. , 3825000. ,  796603.5,
#         756000. , 1021500. , 1300500. , 2475000. , 1251000. ,  177444. ,
#         470511. , 1278000. , 1773000. ,  933300. , 1638000. ,  471951. ,
#         478795.5, 1256103. , 1507500. ,  264312. ,  862353. ,  378598.5,
#         482530.5, 1687500. , 1890000. , 1462500. , 1422000. , 1597500. ,
#         232690.5, 1179000. , 1647000. , 1534500. ,  885429. , 1669500. ,
#         737784. ,  502893. ,  420390. ,  366516. , 1188000. , 1185925.5,
#        1737000. , 1219500. ,  619150.5,  442062. , 1557000. , 1750500. ,
#        1480500. , 1777500. , 1224000. , 1593000. , 1651500. ,  676278. ,
#         193959. ,  238531.5, 1449000. ,  155965.5, 1044000. , 1176727.5,
#        1795500. , 1516500. , 1764000. ,  435100.5, 1439248.5, 1404000. ,
#         630400.5, 1521000. , 1494000. ,  300838.5,  592533. ,  728473.5,
#        1629000. , 1831500. ,  466713. , 2115000. , 1386000. , 1732500. ,
#        1246500. ,  983713.5,  836154. ,  761836.5, 1984500. , 1259563.5,
#         196285.5, 1566000. , 1255500. , 1786500. , 1746000. , 1818000. ,
#        1678500. , 1728000. ,  244435.5,  567544.5,  857538. , 1525500. ,
#         955003.5,  259312.5,  644724. , 1998000. ,  737860.5,  455548.5,
#         437476.5, 1444500. , 1791000. , 2700000. , 1426500. , 1759500. ,
#         450234. , 1503000. ,  413442. ,  467874. ,  385456.5,  241024.5,
#        1935000. , 2218500. ,  409986. , 1980000. , 1471500. ,  577345.5,
#         316372.5,  458806.5, 1683000. ,  642915. ,  683023.5,  905287.5,
#          60070.5,  812983.5, 1804500. , 1431000. , 1220022. , 1633500. ,
#         186390. ,  827100. , 1849500. , 1953000. ,  382257. ,  370219.5,
#         289539. , 1399500. ,  857655. ,  377167.5, 1741500. ,  331245. ,
#        1782000. , 1908000. , 1957500. ,  333630. , 1903500. ,  843093. ,
#         785943. ,  527823. , 1719000. ,  848704.5,  499563. , 1067553. ,
#         568867.5, 1543500. ,  601389. ,  472545. , 2047500. , 1615500. ,
#         521194.5,  214146. ,  444010.5, 1827000. ,  705361.5,  268420.5,
#         369256.5, 2133000. ,  862893. ,  646330.5, 1854000. ,  464463. ,
#         328648.5,  378189. ,  161658. ,  367879.5,  584820. ,  668506.5,
#         436801.5, 2038500. , 1388862. ,  592452. ,  439479. ,  447804. ,
#         323982. , 3150000. ,  894654. , 1989000. ,   67392. , 2007000. ,
#        2106000. , 1674000. ,  447606. , 1962000. ,  532624.5,  810778.5,
#        1660500. , 2223000. ,  411417. , 1930500. ,  853195.5, 1714500. ,
#        1199308.5,  208408.5,  766813.5, 2137500. ,  581184. ,  546021. ,
#         296671.5, 1624500. ,  367821. ,  535774.5,  280026. , 1481535. ,
#        1912500. ,  702301.5, 3555000. ,  428994. ,  288787.5,  685336.5,
#         635085. ,  970006.5, 2070000. ,  275760. ,  486085.5, 2169000. ,
#         242626.5,  762246. ,  312790.5,  612238.5,  415359. , 1867500. ,
#        2119500. ,  393534. ,  476284.5,  933174. ,  445603.5,  734976. ,
#        4050000. ,  855175.5,  808245. ,  552595.5,  443421. , 1639431. ,
#         844240.5, 2074500. ,  281907. , 1408500. ,  522544.5,  263965.5,
#         427468.5,  388674. ,  281380.5, 1677942. ,  596488.5,  545251.5,
#         868594.5,  303696. , 1966500. ,  325804.5, 2448000. ,  295677. ,
#         906642. , 1015519.5,  404707.5, 1076436. ,  635652. ,  569097. ,
#         659380.5,  338598. , 1307092.5,  121945.5,  769909.5,  379251. ,
#         943150.5, 2272500. ,  349834.5, 1692000. , 1458859.5, 1064326.5,
#        2362500. ,  793296. ,  967540.5,  208525.5,  852574.5,  400887. ,
#         692914.5,  462406.5, 2114100. ,  389623.5, 1177744.5, 1921500. ,
#         303651. , 1078713. ,  618903. ,  885523.5,  498856.5, 1147711.5,
#        2232306. ,  683613. ,  852975. , 2124000. , 1993500. ,  885154.5,
#        1290766.5,  887949. ,  446998.5,  372712.5,  280894.5,  675981. ,
#         933763.5,  705892.5,  379867.5,  418828.5, 1127628. ,  394038. ,
#        1474663.5,  234805.5,  324819. , 2101500. , 1840500. ,  330390. ,
#         682609.5,  441733.5,  675382.5,  887314.5,  507618. ,  342823.5,
#         645799.5,  494208. ,  607671. ,  782059.5,  424039.5,  201928.5,
#         658246.5,  350068.5,  295776. , 1496893.5,  381528. ,  357133.5,
#         784579.5,  393799.5,  350500.5,  801270. ,  671179.5, 2011500. ,
#         405225. , 2151000. , 1199371.5, 1223964. ,  749997. , 1944000. ,
#        1996456.5,  285727.5,  343840.5,  250398. ,  199633.5,  859842. ,
#        2187000. ,  421213.5, 2065500. ,   84028.5, 1415259. ,  282667.5,
#         231043.5, 1723666.5, 1701000. ,  505080. ,  413910. ,  478134. ,
#         933493.5,  198229.5,  938497.5,  772600.5,  832878. ,  537282. ,
#        2281500. ,  760986. ,  863149.5, 2191500. ,  869715. ,  655704. ,
#        2196000. , 2092500. ,  394101. , 2142000. ,  241704. ,  430447.5,
#         239967. ,  594558. , 1894500. ,  418473. ,  912505.5,  598887. ,
#         354015. ,  323604. ,  443182.5, 2146500. ,  810022.5,  644962.5,
#         410274. ,  205533. , 1058976. ,  466083. ,  552384. ,  969241.5,
#         383035.5,  137142. ,  304798.5,  778801.5,  872739. , 1039315.5,
#        2385000. ,  620424. ,  891418.5,  121878. ,  430915.5,  460858.5,
#         607603.5,  965794.5,  584995.5,  942201. ,  517050. ,  559836. ,
#        2155500. , 1305706.5,  503559. ,  718110. ,  346099.5, 1948500. ,
#         917365.5,  556794. ,  178344. ,  851769. , 3060000. ,  274810.5,
#         459148.5,  997281. ,  159066. ,  619776. , 1805922. ,  635008.5,
#         202914. , 1181466. ,   40500. ,  607608. ,  991476. ,  751662. ,
#         384772.5, 1324962. ,  766444.5,  264600. , 1247643. ,  425326.5,
#         894825. ,  453465. ,  743863.5])

# %%
df2["OBS_30_CNT_SOCIAL_CIRCLE"]. fillna(df2["OBS_30_CNT_SOCIAL_CIRCLE"].mode().iloc[0],inplace=True)
df2["DEF_30_CNT_SOCIAL_CIRCLE"]. fillna(df2["DEF_30_CNT_SOCIAL_CIRCLE"].mode().iloc[0],inplace=True)
df2["AMT_ANNUITY_x"].fillna(df2["AMT_ANNUITY_x"].median(),inplace=True)
df2["AMT_CREDIT_x"].fillna(df2["AMT_CREDIT_x"].median(),inplace=True)
df2["AMT_GOODS_PRICE_x"].fillna(df2["AMT_GOODS_PRICE_x"].median(),inplace=True)
df2["AMT_REQ_CREDIT_BUREAU_MON"].fillna(df2["AMT_REQ_CREDIT_BUREAU_MON"].median(),inplace=True)
df2["AMT_REQ_CREDIT_BUREAU_YEAR"].fillna(df2["AMT_REQ_CREDIT_BUREAU_YEAR"].median(),inplace=True)
df2["AMT_GOODS_PRICE_x"].fillna(df2["AMT_GOODS_PRICE_x"].median(),inplace=True)
df2['DAYS_LAST_PHONE_CHANGE'].fillna(df2["DAYS_LAST_PHONE_CHANGE"].median(),inplace=True)
df2['DAYS_REGISTRATION'].fillna(df2["DAYS_REGISTRATION"].median(),inplace=True)
df2['DAYS_ID_PUBLISH'].fillna(df2["DAYS_ID_PUBLISH"].median(),inplace=True)

# %%
df2.describe().T # statistical summary
# Out:
#                                count           mean            std  \
# TARGET                      956121.0       0.094639       0.292715
# DAYS_BIRTH                  956121.0  -14961.033096    3612.126372
# CNT_CHILDREN                956121.0       0.497461       0.765035
# AMT_INCOME_TOTAL            956121.0  179799.644959  228781.084936
# AMT_CREDIT_x                956121.0  597602.809791  385007.685269
# AMT_ANNUITY_x               956121.0   27755.516189   14009.263039
# AMT_GOODS_PRICE_x           956121.0  536232.074909  353069.486183
# NAME_EDUCATION_TYPE         956121.0       0.335433       0.594988
# DAYS_EMPLOYED               956121.0   -2437.763144    2831.328460
# OCCUPATION_TYPE             956121.0       7.928290       4.424132
# CNT_FAM_MEMBERS             956121.0       2.269316       0.932909
# REGION_RATING_CLIENT        956121.0       2.057545       0.496085
# EXT_SOURCE_3                956121.0       0.483870       0.180181
# DAYS_REGISTRATION           956121.0   -4627.163123    3265.891599
# DAYS_ID_PUBLISH             956121.0   -2830.640985    1517.369034
# FLAG_MOBIL                  956121.0       1.000000       0.000000
# FLAG_WORK_PHONE             956121.0       0.225989       0.418232
# FLAG_PHONE                  956121.0       0.280122       0.449059
# FLAG_EMAIL                  956121.0       0.080163       0.271546
# DAYS_LAST_PHONE_CHANGE      956121.0   -1092.006711     802.970160
# HOUR_APPR_PROCESS_START_x   956121.0      12.109839       3.271082
# REG_CITY_NOT_LIVE_CITY      956121.0       0.085906       0.280226
# REG_CITY_NOT_WORK_CITY      956121.0       0.274845       0.446436
# LIVE_CITY_NOT_WORK_CITY     956121.0       0.215233       0.410984
# ORGANIZATION_TYPE           956121.0      24.460656      17.605763
# AMT_REQ_CREDIT_BUREAU_YEAR  956121.0       2.713087       2.025385
# AMT_REQ_CREDIT_BUREAU_MON   956121.0       0.281130       0.949740
# OBS_30_CNT_SOCIAL_CIRCLE    956121.0       1.544211       2.536669
# DEF_30_CNT_SOCIAL_CIRCLE    956121.0       0.150579       0.460600
#
#                                      min            25%           50%  \
# TARGET                          0.000000       0.000000       0.00000
# DAYS_BIRTH                 -25200.000000  -17667.000000  -14785.00000
# CNT_CHILDREN                    0.000000       0.000000       0.00000
# AMT_INCOME_TOTAL            25650.000000  112500.000000  157500.00000
# AMT_CREDIT_x                45000.000000  284256.000000  518562.00000
# AMT_ANNUITY_x                1980.000000   17509.500000   25960.50000
# AMT_GOODS_PRICE_x           40500.000000  247500.000000  450000.00000
# NAME_EDUCATION_TYPE             0.000000       0.000000       0.00000
# DAYS_EMPLOYED              -17912.000000   -3240.000000   -1747.00000
# OCCUPATION_TYPE                 0.000000       4.000000       8.00000
# CNT_FAM_MEMBERS                 1.000000       2.000000       2.00000
# REGION_RATING_CLIENT            1.000000       2.000000       2.00000
# EXT_SOURCE_3                    0.000527       0.367291       0.51009
# DAYS_REGISTRATION          -22928.000000   -6954.000000   -4251.00000
# DAYS_ID_PUBLISH             -7197.000000   -4196.000000   -2945.00000
# FLAG_MOBIL                      1.000000       1.000000       1.00000
# FLAG_WORK_PHONE                 0.000000       0.000000       0.00000
# FLAG_PHONE                      0.000000       0.000000       0.00000
# FLAG_EMAIL                      0.000000       0.000000       0.00000
# DAYS_LAST_PHONE_CHANGE      -4292.000000   -1694.000000   -1013.00000
# HOUR_APPR_PROCESS_START_x       0.000000      10.000000      12.00000
# REG_CITY_NOT_LIVE_CITY          0.000000       0.000000       0.00000
# REG_CITY_NOT_WORK_CITY          0.000000       0.000000       0.00000
# LIVE_CITY_NOT_WORK_CITY         0.000000       0.000000       0.00000
# ORGANIZATION_TYPE               0.000000       5.000000      28.00000
# AMT_REQ_CREDIT_BUREAU_YEAR      0.000000       1.000000       2.00000
# AMT_REQ_CREDIT_BUREAU_MON       0.000000       0.000000       0.00000
# OBS_30_CNT_SOCIAL_CIRCLE        0.000000       0.000000       0.00000
# DEF_30_CNT_SOCIAL_CIRCLE        0.000000       0.000000       0.00000
#
#                                       75%           max
# TARGET                           0.000000  1.000000e+00
# DAYS_BIRTH                  -12011.000000 -7.489000e+03
# CNT_CHILDREN                     1.000000  1.900000e+01
# AMT_INCOME_TOTAL            225000.000000  1.170000e+08
# AMT_CREDIT_x                808650.000000  4.050000e+06
# AMT_ANNUITY_x                35523.000000  2.250000e+05
# AMT_GOODS_PRICE_x           684000.000000  4.050000e+06
# NAME_EDUCATION_TYPE              1.000000  4.000000e+00
# DAYS_EMPLOYED                 -842.000000  3.652430e+05
# OCCUPATION_TYPE                 11.000000  1.700000e+01
# CNT_FAM_MEMBERS                  3.000000  2.000000e+01
# REGION_RATING_CLIENT             2.000000  3.000000e+00
# EXT_SOURCE_3                     0.609276  8.939761e-01
# DAYS_REGISTRATION            -1825.000000  0.000000e+00
# DAYS_ID_PUBLISH              -1530.000000  0.000000e+00
# FLAG_MOBIL                       1.000000  1.000000e+00
# FLAG_WORK_PHONE                  0.000000  1.000000e+00
# FLAG_PHONE                       1.000000  1.000000e+00
# FLAG_EMAIL                       0.000000  1.000000e+00
# DAYS_LAST_PHONE_CHANGE        -403.000000  0.000000e+00
# HOUR_APPR_PROCESS_START_x       14.000000  2.300000e+01
# REG_CITY_NOT_LIVE_CITY           0.000000  1.000000e+00
# REG_CITY_NOT_WORK_CITY           1.000000  1.000000e+00
# LIVE_CITY_NOT_WORK_CITY          0.000000  1.000000e+00
# ORGANIZATION_TYPE               42.000000  5.700000e+01
# AMT_REQ_CREDIT_BUREAU_YEAR       4.000000  2.300000e+01
# AMT_REQ_CREDIT_BUREAU_MON        0.000000  2.400000e+01
# OBS_30_CNT_SOCIAL_CIRCLE         2.000000  3.480000e+02
# DEF_30_CNT_SOCIAL_CIRCLE         0.000000  3.400000e+01

# %%
# fit & transform the encoded variables
df2["NAME_FAMILY_STATUS"]= LabelEncoder().fit_transform(df2[["NAME_FAMILY_STATUS"]])
df2["NAME_CONTRACT_TYPE_x"]= LabelEncoder().fit_transform(df2[["NAME_CONTRACT_TYPE_x"]])
df2["CODE_GENDER"]= LabelEncoder().fit_transform(df2[["CODE_GENDER"]])
df2["FLAG_OWN_CAR"]= LabelEncoder().fit_transform(df2[["FLAG_OWN_CAR"]])
df2["FLAG_OWN_REALTY"]= LabelEncoder().fit_transform(df2[["FLAG_OWN_REALTY"]])
df2["NAME_INCOME_TYPE"]= LabelEncoder().fit_transform(df2[["NAME_INCOME_TYPE"]])
df2["NAME_HOUSING_TYPE"]= LabelEncoder().fit_transform(df2[["NAME_HOUSING_TYPE"]])

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 956121 entries, 0 to 956120
# Data columns (total 38 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   TARGET                        956121 non-null  int64
#  1   CODE_GENDER                   956121 non-null  int32
#  2   DAYS_BIRTH                    956121 non-null  int64
#  3   FLAG_OWN_CAR                  956121 non-null  int32
#  4   FLAG_OWN_REALTY               956121 non-null  int32
#  5   CNT_CHILDREN                  956121 non-null  int64
#  6   AMT_INCOME_TOTAL              956121 non-null  float64
#  7   AMT_CREDIT_x                  956121 non-null  float64
#  8   AMT_ANNUITY_x                 956121 non-null  float64
#  9   AMT_GOODS_PRICE_x             956121 non-null  float64
#  10  NAME_INCOME_TYPE              956121 non-null  int32
#  11  NAME_EDUCATION_TYPE           956121 non-null  int64
#  12  NAME_FAMILY_STATUS            956121 non-null  int32
#  13  NAME_HOUSING_TYPE             956121 non-null  int32
#  14  DAYS_EMPLOYED                 956121 non-null  int64
#  15  OCCUPATION_TYPE               956121 non-null  int32
#  16  CNT_FAM_MEMBERS               956121 non-null  float64
#  17  REGION_RATING_CLIENT          956121 non-null  int64
#  18  EXT_SOURCE_3                  956121 non-null  float64
#  19  DAYS_REGISTRATION             956121 non-null  float64
#  20  DAYS_ID_PUBLISH               956121 non-null  int64
#  21  FLAG_MOBIL                    956121 non-null  int64
#  22  FLAG_WORK_PHONE               956121 non-null  int64
#  23  FLAG_PHONE                    956121 non-null  int64
#  24  FLAG_EMAIL                    956121 non-null  int64
#  25  DAYS_LAST_PHONE_CHANGE        956121 non-null  float64
#  26  WEEKDAY_APPR_PROCESS_START_x  956121 non-null  object
#  27  HOUR_APPR_PROCESS_START_x     956121 non-null  int64
#  28  REG_CITY_NOT_LIVE_CITY        956121 non-null  int64
#  29  REG_CITY_NOT_WORK_CITY        956121 non-null  int64
#  30  LIVE_CITY_NOT_WORK_CITY       956121 non-null  int64
#  31  NAME_CONTRACT_TYPE_x          956121 non-null  int32
#  32  ORGANIZATION_TYPE             956121 non-null  int32
#  33  AMT_REQ_CREDIT_BUREAU_YEAR    956121 non-null  float64
#  34  AMT_REQ_CREDIT_BUREAU_MON     956121 non-null  float64
#  35  OBS_30_CNT_SOCIAL_CIRCLE      956121 non-null  float64
#  36  DEF_30_CNT_SOCIAL_CIRCLE      956121 non-null  float64
#  37  NAME_CONTRACT_STATUS          956121 non-null  object
# dtypes: float64(12), int32(9), int64(15), object(2)
# memory usage: 244.4+ MB

# %%
# detecting the skewed columns using plot

def skewplot(df2, column):
    plt.figure(figsize=(20, 4))

    # Distplot
    plt.subplot(1, 3, 1)
    sns.distplot(df2[column], kde=True)
    plt.title("Distplot for " + column)


    # Boxplot
    plt.subplot(1, 3, 2)
    sns.boxplot(df2[column])
    plt.title("Box plot for " + column)

    # Violin plot
    plt.subplot(1, 3, 3)
    sns.violinplot(df2[column])
    plt.title("Violin plot for " + column)

    plt.tight_layout()
    plt.show()

# %%
skewed_columns=['AMT_INCOME_TOTAL','CODE_GENDER','FLAG_OWN_CAR','AMT_CREDIT_x', 'AMT_ANNUITY_x', 'DAYS_EMPLOYED',
    'OCCUPATION_TYPE', 'NAME_EDUCATION_TYPE', 'NAME_FAMILY_STATUS','NAME_HOUSING_TYPE',
    'AMT_GOODS_PRICE_x', 'OBS_30_CNT_SOCIAL_CIRCLE', 'DEF_30_CNT_SOCIAL_CIRCLE',
    'TARGET']

for column in skewed_columns:
    skewplot(df2, column)

# %%
df2.describe().T
# Out:
#                                count           mean            std  \
# TARGET                      956121.0       0.094639       0.292715
# CODE_GENDER                 956121.0       0.376686       0.484618
# DAYS_BIRTH                  956121.0  -14961.033096    3612.126372
# FLAG_OWN_CAR                956121.0       0.382428       0.485980
# FLAG_OWN_REALTY             956121.0       0.710028       0.453749
# CNT_CHILDREN                956121.0       0.497461       0.765035
# AMT_INCOME_TOTAL            956121.0  179799.644959  228781.084936
# AMT_CREDIT_x                956121.0  597602.809791  385007.685269
# AMT_ANNUITY_x               956121.0   27755.516189   14009.263039
# AMT_GOODS_PRICE_x           956121.0  536232.074909  353069.486183
# NAME_INCOME_TYPE            956121.0       3.441786       2.207390
# NAME_EDUCATION_TYPE         956121.0       0.335433       0.594988
# NAME_FAMILY_STATUS          956121.0       1.313437       0.937456
# NAME_HOUSING_TYPE           956121.0       1.312586       0.988122
# DAYS_EMPLOYED               956121.0   -2437.763144    2831.328460
# OCCUPATION_TYPE             956121.0       7.928290       4.424132
# CNT_FAM_MEMBERS             956121.0       2.269316       0.932909
# REGION_RATING_CLIENT        956121.0       2.057545       0.496085
# EXT_SOURCE_3                956121.0       0.483870       0.180181
# DAYS_REGISTRATION           956121.0   -4627.163123    3265.891599
# DAYS_ID_PUBLISH             956121.0   -2830.640985    1517.369034
# FLAG_MOBIL                  956121.0       1.000000       0.000000
# FLAG_WORK_PHONE             956121.0       0.225989       0.418232
# FLAG_PHONE                  956121.0       0.280122       0.449059
# FLAG_EMAIL                  956121.0       0.080163       0.271546
# DAYS_LAST_PHONE_CHANGE      956121.0   -1092.006711     802.970160
# HOUR_APPR_PROCESS_START_x   956121.0      12.109839       3.271082
# REG_CITY_NOT_LIVE_CITY      956121.0       0.085906       0.280226
# REG_CITY_NOT_WORK_CITY      956121.0       0.274845       0.446436
# LIVE_CITY_NOT_WORK_CITY     956121.0       0.215233       0.410984
# NAME_CONTRACT_TYPE_x        956121.0       0.079942       0.271203
# ORGANIZATION_TYPE           956121.0      24.460656      17.605763
# AMT_REQ_CREDIT_BUREAU_YEAR  956121.0       2.713087       2.025385
# AMT_REQ_CREDIT_BUREAU_MON   956121.0       0.281130       0.949740
# OBS_30_CNT_SOCIAL_CIRCLE    956121.0       1.544211       2.536669
# DEF_30_CNT_SOCIAL_CIRCLE    956121.0       0.150579       0.460600
#
#                                      min            25%           50%  \
# TARGET                          0.000000       0.000000       0.00000
# CODE_GENDER                     0.000000       0.000000       0.00000
# DAYS_BIRTH                 -25200.000000  -17667.000000  -14785.00000
# FLAG_OWN_CAR                    0.000000       0.000000       0.00000
# FLAG_OWN_REALTY                 0.000000       0.000000       1.00000
# CNT_CHILDREN                    0.000000       0.000000       0.00000
# AMT_INCOME_TOTAL            25650.000000  112500.000000  157500.00000
# AMT_CREDIT_x                45000.000000  284256.000000  518562.00000
# AMT_ANNUITY_x                1980.000000   17509.500000   25960.50000
# AMT_GOODS_PRICE_x           40500.000000  247500.000000  450000.00000
# NAME_INCOME_TYPE                0.000000       0.000000       5.00000
# NAME_EDUCATION_TYPE             0.000000       0.000000       0.00000
# NAME_FAMILY_STATUS              0.000000       1.000000       1.00000
# NAME_HOUSING_TYPE               0.000000       1.000000       1.00000
# DAYS_EMPLOYED              -17912.000000   -3240.000000   -1747.00000
# OCCUPATION_TYPE                 0.000000       4.000000       8.00000
# CNT_FAM_MEMBERS                 1.000000       2.000000       2.00000
# REGION_RATING_CLIENT            1.000000       2.000000       2.00000
# EXT_SOURCE_3                    0.000527       0.367291       0.51009
# DAYS_REGISTRATION          -22928.000000   -6954.000000   -4251.00000
# DAYS_ID_PUBLISH             -7197.000000   -4196.000000   -2945.00000
# FLAG_MOBIL                      1.000000       1.000000       1.00000
# FLAG_WORK_PHONE                 0.000000       0.000000       0.00000
# FLAG_PHONE                      0.000000       0.000000       0.00000
# FLAG_EMAIL                      0.000000       0.000000       0.00000
# DAYS_LAST_PHONE_CHANGE      -4292.000000   -1694.000000   -1013.00000
# HOUR_APPR_PROCESS_START_x       0.000000      10.000000      12.00000
# REG_CITY_NOT_LIVE_CITY          0.000000       0.000000       0.00000
# REG_CITY_NOT_WORK_CITY          0.000000       0.000000       0.00000
# LIVE_CITY_NOT_WORK_CITY         0.000000       0.000000       0.00000
# NAME_CONTRACT_TYPE_x            0.000000       0.000000       0.00000
# ORGANIZATION_TYPE               0.000000       5.000000      28.00000
# AMT_REQ_CREDIT_BUREAU_YEAR      0.000000       1.000000       2.00000
# AMT_REQ_CREDIT_BUREAU_MON       0.000000       0.000000       0.00000
# OBS_30_CNT_SOCIAL_CIRCLE        0.000000       0.000000       0.00000
# DEF_30_CNT_SOCIAL_CIRCLE        0.000000       0.000000       0.00000
#
#                                       75%           max
# TARGET                           0.000000  1.000000e+00
# CODE_GENDER                      1.000000  2.000000e+00
# DAYS_BIRTH                  -12011.000000 -7.489000e+03
# FLAG_OWN_CAR                     1.000000  1.000000e+00
# FLAG_OWN_REALTY                  1.000000  1.000000e+00
# CNT_CHILDREN                     1.000000  1.900000e+01
# AMT_INCOME_TOTAL            225000.000000  1.170000e+08
# AMT_CREDIT_x                808650.000000  4.050000e+06
# AMT_ANNUITY_x                35523.000000  2.250000e+05
# AMT_GOODS_PRICE_x           684000.000000  4.050000e+06
# NAME_INCOME_TYPE                 5.000000  5.000000e+00
# NAME_EDUCATION_TYPE              1.000000  4.000000e+00
# NAME_FAMILY_STATUS               1.000000  4.000000e+00
# NAME_HOUSING_TYPE                1.000000  5.000000e+00
# DAYS_EMPLOYED                 -842.000000  3.652430e+05
# OCCUPATION_TYPE                 11.000000  1.700000e+01
# CNT_FAM_MEMBERS                  3.000000  2.000000e+01
# REGION_RATING_CLIENT             2.000000  3.000000e+00
# EXT_SOURCE_3                     0.609276  8.939761e-01
# DAYS_REGISTRATION            -1825.000000  0.000000e+00
# DAYS_ID_PUBLISH              -1530.000000  0.000000e+00
# FLAG_MOBIL                       1.000000  1.000000e+00
# FLAG_WORK_PHONE                  0.000000  1.000000e+00
# FLAG_PHONE                       1.000000  1.000000e+00
# FLAG_EMAIL                       0.000000  1.000000e+00
# DAYS_LAST_PHONE_CHANGE        -403.000000  0.000000e+00
# HOUR_APPR_PROCESS_START_x       14.000000  2.300000e+01
# REG_CITY_NOT_LIVE_CITY           0.000000  1.000000e+00
# REG_CITY_NOT_WORK_CITY           1.000000  1.000000e+00
# LIVE_CITY_NOT_WORK_CITY          0.000000  1.000000e+00
# NAME_CONTRACT_TYPE_x             0.000000  1.000000e+00
# ORGANIZATION_TYPE               42.000000  5.700000e+01
# AMT_REQ_CREDIT_BUREAU_YEAR       4.000000  2.300000e+01
# AMT_REQ_CREDIT_BUREAU_MON        0.000000  2.400000e+01
# OBS_30_CNT_SOCIAL_CIRCLE         2.000000  3.480000e+02
# DEF_30_CNT_SOCIAL_CIRCLE         0.000000  3.400000e+01

# %%
df3= df2.copy()
df3.columns
# Out:
# Index(['TARGET', 'CODE_GENDER', 'DAYS_BIRTH', 'FLAG_OWN_CAR',
#        'FLAG_OWN_REALTY', 'CNT_CHILDREN', 'AMT_INCOME_TOTAL', 'AMT_CREDIT_x',
#        'AMT_ANNUITY_x', 'AMT_GOODS_PRICE_x', 'NAME_INCOME_TYPE',
#        'NAME_EDUCATION_TYPE', 'NAME_FAMILY_STATUS', 'NAME_HOUSING_TYPE',
#        'DAYS_EMPLOYED', 'OCCUPATION_TYPE', 'CNT_FAM_MEMBERS',
#        'REGION_RATING_CLIENT', 'EXT_SOURCE_3', 'DAYS_REGISTRATION',
#        'DAYS_ID_PUBLISH', 'FLAG_MOBIL', 'FLAG_WORK_PHONE', 'FLAG_PHONE',
#        'FLAG_EMAIL', 'DAYS_LAST_PHONE_CHANGE', 'WEEKDAY_APPR_PROCESS_START_x',
#        'HOUR_APPR_PROCESS_START_x', 'REG_CITY_NOT_LIVE_CITY',
#        'REG_CITY_NOT_WORK_CITY', 'LIVE_CITY_NOT_WORK_CITY',
#        'NAME_CONTRACT_TYPE_x', 'ORGANIZATION_TYPE',
#        'AMT_REQ_CREDIT_BUREAU_YEAR', 'AMT_REQ_CREDIT_BUREAU_MON',
#        'OBS_30_CNT_SOCIAL_CIRCLE', 'DEF_30_CNT_SOCIAL_CIRCLE',
#        'NAME_CONTRACT_STATUS'],
#       dtype='object')

# %%
import numpy as np

# Apply square root transformation to the specified columns

df3["AMT_INCOME_TOTAL_sqrt"] = np.sqrt(df3["AMT_INCOME_TOTAL"])
df3["AMT_CREDIT_x_sqrt"] = np.sqrt(df3["AMT_CREDIT_x"])
df3["AMT_ANNUITY_x_sqrt"] = np.sqrt(df3["AMT_ANNUITY_x"])
df3["CODE_GENDER_sqrt"] = np.sqrt(df3["CODE_GENDER"])
df3["FLAG_OWN_CAR_sqrt"] = np.sqrt(df3["FLAG_OWN_CAR"])

df3["DAYS_EMPLOYED_sqrt"] = np.sqrt(df3["DAYS_EMPLOYED"])
df3["OCCUPATION_TYPE_sqrt"] = np.sqrt(df3["OCCUPATION_TYPE"])
df3["NAME_EDUCATION_TYPE_sqrt"] = np.sqrt(df3["NAME_EDUCATION_TYPE"])
df3["NAME_HOUSING_TYPE_sqrt"] = np.sqrt(df3["NAME_HOUSING_TYPE"])


df3["NAME_FAMILY_STATUS_sqrt"] = np.sqrt(df3["NAME_FAMILY_STATUS"])
df3["AMT_GOODS_PRICE_x_sqrt"] = np.sqrt(df3["AMT_GOODS_PRICE_x"])
df3["OBS_30_CNT_SOCIAL_CIRCLE_sqrt"] = np.sqrt(df3["OBS_30_CNT_SOCIAL_CIRCLE"])
df3["DEF_30_CNT_SOCIAL_CIRCLE_sqrt"] = np.sqrt(df3["DEF_30_CNT_SOCIAL_CIRCLE"])

# %%
skwed_columns_2=["AMT_INCOME_TOTAL_sqrt","CODE_GENDER_sqrt","FLAG_OWN_CAR_sqrt","AMT_CREDIT_x_sqrt","AMT_ANNUITY_x_sqrt","DAYS_EMPLOYED_sqrt","OCCUPATION_TYPE_sqrt","NAME_EDUCATION_TYPE_sqrt","NAME_HOUSING_TYPE_sqrt","NAME_FAMILY_STATUS_sqrt","AMT_GOODS_PRICE_x_sqrt","OBS_30_CNT_SOCIAL_CIRCLE_sqrt","DEF_30_CNT_SOCIAL_CIRCLE_sqrt"]
for i in skwed_columns_2:
  skewplot(df3,i)

# %%
# Outliers Handling - Interquartile Range(IQR) Method
df4= df3.copy()
def outlier(df,column):
  q1= df[column].quantile(0.25)
  q3= df[column].quantile(0.75)

  iqr= q3-q1

  upper_threshold= q3 + (1.5*iqr)
  lower_threshold= q1 - (1.5*iqr)

  df[column]= df[column].clip(lower_threshold, upper_threshold)

# %%
df4.describe().T
# Out:
#                                   count           mean            std  \
# TARGET                         956121.0       0.094639       0.292715
# CODE_GENDER                    956121.0       0.376686       0.484618
# DAYS_BIRTH                     956121.0  -14961.033096    3612.126372
# FLAG_OWN_CAR                   956121.0       0.382428       0.485980
# FLAG_OWN_REALTY                956121.0       0.710028       0.453749
# CNT_CHILDREN                   956121.0       0.497461       0.765035
# AMT_INCOME_TOTAL               956121.0  179799.644959  228781.084936
# AMT_CREDIT_x                   956121.0  597602.809791  385007.685269
# AMT_ANNUITY_x                  956121.0   27755.516189   14009.263039
# AMT_GOODS_PRICE_x              956121.0  536232.074909  353069.486183
# NAME_INCOME_TYPE               956121.0       3.441786       2.207390
# NAME_EDUCATION_TYPE            956121.0       0.335433       0.594988
# NAME_FAMILY_STATUS             956121.0       1.313437       0.937456
# NAME_HOUSING_TYPE              956121.0       1.312586       0.988122
# DAYS_EMPLOYED                  956121.0   -2437.763144    2831.328460
# OCCUPATION_TYPE                956121.0       7.928290       4.424132
# CNT_FAM_MEMBERS                956121.0       2.269316       0.932909
# REGION_RATING_CLIENT           956121.0       2.057545       0.496085
# EXT_SOURCE_3                   956121.0       0.483870       0.180181
# DAYS_REGISTRATION              956121.0   -4627.163123    3265.891599
# DAYS_ID_PUBLISH                956121.0   -2830.640985    1517.369034
# FLAG_MOBIL                     956121.0       1.000000       0.000000
# FLAG_WORK_PHONE                956121.0       0.225989       0.418232
# FLAG_PHONE                     956121.0       0.280122       0.449059
# FLAG_EMAIL                     956121.0       0.080163       0.271546
# DAYS_LAST_PHONE_CHANGE         956121.0   -1092.006711     802.970160
# HOUR_APPR_PROCESS_START_x      956121.0      12.109839       3.271082
# REG_CITY_NOT_LIVE_CITY         956121.0       0.085906       0.280226
# REG_CITY_NOT_WORK_CITY         956121.0       0.274845       0.446436
# LIVE_CITY_NOT_WORK_CITY        956121.0       0.215233       0.410984
# NAME_CONTRACT_TYPE_x           956121.0       0.079942       0.271203
# ORGANIZATION_TYPE              956121.0      24.460656      17.605763
# AMT_REQ_CREDIT_BUREAU_YEAR     956121.0       2.713087       2.025385
# AMT_REQ_CREDIT_BUREAU_MON      956121.0       0.281130       0.949740
# OBS_30_CNT_SOCIAL_CIRCLE       956121.0       1.544211       2.536669
# DEF_30_CNT_SOCIAL_CIRCLE       956121.0       0.150579       0.460600
# AMT_INCOME_TOTAL_sqrt          956121.0     412.072655      99.978911
# AMT_CREDIT_x_sqrt              956121.0     733.926029     242.807444
# AMT_ANNUITY_x_sqrt             956121.0     161.489249      40.948019
# CODE_GENDER_sqrt               956121.0       0.376668       0.484569
# FLAG_OWN_CAR_sqrt              956121.0       0.382428       0.485980
# DAYS_EMPLOYED_sqrt                 24.0     478.446421     250.716672
# OCCUPATION_TYPE_sqrt           956121.0       2.650108       0.951429
# NAME_EDUCATION_TYPE_sqrt       956121.0       0.302045       0.494169
# NAME_HOUSING_TYPE_sqrt         956121.0       1.100215       0.319553
# NAME_FAMILY_STATUS_sqrt        956121.0       1.045858       0.468635
# AMT_GOODS_PRICE_x_sqrt         956121.0     694.361927     232.580408
# OBS_30_CNT_SOCIAL_CIRCLE_sqrt  956121.0       0.802883       0.948468
# DEF_30_CNT_SOCIAL_CIRCLE_sqrt  956121.0       0.131528       0.365075
#
#                                         min            25%            50%  \
# TARGET                             0.000000       0.000000       0.000000
# CODE_GENDER                        0.000000       0.000000       0.000000
# DAYS_BIRTH                    -25200.000000  -17667.000000  -14785.000000
# FLAG_OWN_CAR                       0.000000       0.000000       0.000000
# FLAG_OWN_REALTY                    0.000000       0.000000       1.000000
# CNT_CHILDREN                       0.000000       0.000000       0.000000
# AMT_INCOME_TOTAL               25650.000000  112500.000000  157500.000000
# AMT_CREDIT_x                   45000.000000  284256.000000  518562.000000
# AMT_ANNUITY_x                   1980.000000   17509.500000   25960.500000
# AMT_GOODS_PRICE_x              40500.000000  247500.000000  450000.000000
# NAME_INCOME_TYPE                   0.000000       0.000000       5.000000
# NAME_EDUCATION_TYPE                0.000000       0.000000       0.000000
# NAME_FAMILY_STATUS                 0.000000       1.000000       1.000000
# NAME_HOUSING_TYPE                  0.000000       1.000000       1.000000
# DAYS_EMPLOYED                 -17912.000000   -3240.000000   -1747.000000
# OCCUPATION_TYPE                    0.000000       4.000000       8.000000
# CNT_FAM_MEMBERS                    1.000000       2.000000       2.000000
# REGION_RATING_CLIENT               1.000000       2.000000       2.000000
# EXT_SOURCE_3                       0.000527       0.367291       0.510090
# DAYS_REGISTRATION             -22928.000000   -6954.000000   -4251.000000
# DAYS_ID_PUBLISH                -7197.000000   -4196.000000   -2945.000000
# FLAG_MOBIL                         1.000000       1.000000       1.000000
# FLAG_WORK_PHONE                    0.000000       0.000000       0.000000
# FLAG_PHONE                         0.000000       0.000000       0.000000
# FLAG_EMAIL                         0.000000       0.000000       0.000000
# DAYS_LAST_PHONE_CHANGE         -4292.000000   -1694.000000   -1013.000000
# HOUR_APPR_PROCESS_START_x          0.000000      10.000000      12.000000
# REG_CITY_NOT_LIVE_CITY             0.000000       0.000000       0.000000
# REG_CITY_NOT_WORK_CITY             0.000000       0.000000       0.000000
# LIVE_CITY_NOT_WORK_CITY            0.000000       0.000000       0.000000
# NAME_CONTRACT_TYPE_x               0.000000       0.000000       0.000000
# ORGANIZATION_TYPE                  0.000000       5.000000      28.000000
# AMT_REQ_CREDIT_BUREAU_YEAR         0.000000       1.000000       2.000000
# AMT_REQ_CREDIT_BUREAU_MON          0.000000       0.000000       0.000000
# OBS_30_CNT_SOCIAL_CIRCLE           0.000000       0.000000       0.000000
# DEF_30_CNT_SOCIAL_CIRCLE           0.000000       0.000000       0.000000
# AMT_INCOME_TOTAL_sqrt            160.156174     335.410197     396.862697
# AMT_CREDIT_x_sqrt                212.132034     533.156637     720.112491
# AMT_ANNUITY_x_sqrt                44.497191     132.323467     161.122624
# CODE_GENDER_sqrt                   0.000000       0.000000       0.000000
# FLAG_OWN_CAR_sqrt                  0.000000       0.000000       0.000000
# DAYS_EMPLOYED_sqrt                 0.000000     604.353373     604.353373
# OCCUPATION_TYPE_sqrt               0.000000       2.000000       2.828427
# NAME_EDUCATION_TYPE_sqrt           0.000000       0.000000       0.000000
# NAME_HOUSING_TYPE_sqrt             0.000000       1.000000       1.000000
# NAME_FAMILY_STATUS_sqrt            0.000000       1.000000       1.000000
# AMT_GOODS_PRICE_x_sqrt           201.246118     497.493719     670.820393
# OBS_30_CNT_SOCIAL_CIRCLE_sqrt      0.000000       0.000000       0.000000
# DEF_30_CNT_SOCIAL_CIRCLE_sqrt      0.000000       0.000000       0.000000
#
#                                          75%           max
# TARGET                              0.000000  1.000000e+00
# CODE_GENDER                         1.000000  2.000000e+00
# DAYS_BIRTH                     -12011.000000 -7.489000e+03
# FLAG_OWN_CAR                        1.000000  1.000000e+00
# FLAG_OWN_REALTY                     1.000000  1.000000e+00
# CNT_CHILDREN                        1.000000  1.900000e+01
# AMT_INCOME_TOTAL               225000.000000  1.170000e+08
# AMT_CREDIT_x                   808650.000000  4.050000e+06
# AMT_ANNUITY_x                   35523.000000  2.250000e+05
# AMT_GOODS_PRICE_x              684000.000000  4.050000e+06
# NAME_INCOME_TYPE                    5.000000  5.000000e+00
# NAME_EDUCATION_TYPE                 1.000000  4.000000e+00
# NAME_FAMILY_STATUS                  1.000000  4.000000e+00
# NAME_HOUSING_TYPE                   1.000000  5.000000e+00
# DAYS_EMPLOYED                    -842.000000  3.652430e+05
# OCCUPATION_TYPE                    11.000000  1.700000e+01
# CNT_FAM_MEMBERS                     3.000000  2.000000e+01
# REGION_RATING_CLIENT                2.000000  3.000000e+00
# EXT_SOURCE_3                        0.609276  8.939761e-01
# DAYS_REGISTRATION               -1825.000000  0.000000e+00
# DAYS_ID_PUBLISH                 -1530.000000  0.000000e+00
# FLAG_MOBIL                          1.000000  1.000000e+00
# FLAG_WORK_PHONE                     0.000000  1.000000e+00
# FLAG_PHONE                          1.000000  1.000000e+00
# FLAG_EMAIL                          0.000000  1.000000e+00
# DAYS_LAST_PHONE_CHANGE           -403.000000  0.000000e+00
# HOUR_APPR_PROCESS_START_x          14.000000  2.300000e+01
# REG_CITY_NOT_LIVE_CITY              0.000000  1.000000e+00
# REG_CITY_NOT_WORK_CITY              1.000000  1.000000e+00
# LIVE_CITY_NOT_WORK_CITY             0.000000  1.000000e+00
# NAME_CONTRACT_TYPE_x                0.000000  1.000000e+00
# ORGANIZATION_TYPE                  42.000000  5.700000e+01
# AMT_REQ_CREDIT_BUREAU_YEAR          4.000000  2.300000e+01
# AMT_REQ_CREDIT_BUREAU_MON           0.000000  2.400000e+01
# OBS_30_CNT_SOCIAL_CIRCLE            2.000000  3.480000e+02
# DEF_30_CNT_SOCIAL_CIRCLE            0.000000  3.400000e+01
# AMT_INCOME_TOTAL_sqrt             474.341649  1.081665e+04
# AMT_CREDIT_x_sqrt                 899.249687  2.012461e+03
# AMT_ANNUITY_x_sqrt                188.475463  4.743416e+02
# CODE_GENDER_sqrt                    1.000000  1.414214e+00
# FLAG_OWN_CAR_sqrt                   1.000000  1.000000e+00
# DAYS_EMPLOYED_sqrt                604.353373  6.043534e+02
# OCCUPATION_TYPE_sqrt                3.316625  4.123106e+00
# NAME_EDUCATION_TYPE_sqrt            1.000000  2.000000e+00
# NAME_HOUSING_TYPE_sqrt              1.000000  2.236068e+00
# NAME_FAMILY_STATUS_sqrt             1.000000  2.000000e+00
# AMT_GOODS_PRICE_x_sqrt            827.042925  2.012461e+03
# OBS_30_CNT_SOCIAL_CIRCLE_sqrt       1.414214  1.865476e+01
# DEF_30_CNT_SOCIAL_CIRCLE_sqrt       0.000000  5.830952e+00

# %%
outlier_columns = ['AMT_INCOME_TOTAL_sqrt','CODE_GENDER_sqrt','FLAG_OWN_CAR_sqrt',
       'AMT_CREDIT_x_sqrt', 'AMT_ANNUITY_x_sqrt', 'DAYS_EMPLOYED_sqrt',
       'OCCUPATION_TYPE_sqrt', 'NAME_EDUCATION_TYPE_sqrt','NAME_HOUSING_TYPE_sqrt',
       'NAME_FAMILY_STATUS_sqrt', 'AMT_GOODS_PRICE_x_sqrt',
       'OBS_30_CNT_SOCIAL_CIRCLE_sqrt', 'DEF_30_CNT_SOCIAL_CIRCLE_sqrt']
for i in outlier_columns:
  outlier(df4,i)

# %%
for i in outlier_columns:
  skewplot(df4,i)

# %%
dff = df4[['AMT_INCOME_TOTAL_sqrt','CODE_GENDER_sqrt','FLAG_OWN_CAR_sqrt',
       'AMT_CREDIT_x_sqrt', 'AMT_ANNUITY_x_sqrt', 'DAYS_EMPLOYED_sqrt',
       'OCCUPATION_TYPE_sqrt', 'NAME_EDUCATION_TYPE_sqrt',
       'NAME_FAMILY_STATUS_sqrt', 'AMT_GOODS_PRICE_x_sqrt','NAME_HOUSING_TYPE_sqrt',
       'OBS_30_CNT_SOCIAL_CIRCLE_sqrt', 'DEF_30_CNT_SOCIAL_CIRCLE_sqrt',"TARGET"]]

# %%
# Check for constant columns
constant_columns = [col for col in dff.columns if dff[col].nunique() <= 1]
print("Constant Columns:", constant_columns)

# Check for NaN values
nan_columns = dff.columns[dff.isna().any()].tolist()
print("Columns with NaN values:", nan_columns)
# Out:
# Constant Columns: ['DAYS_EMPLOYED_sqrt', 'NAME_FAMILY_STATUS_sqrt', 'NAME_HOUSING_TYPE_sqrt', 'DEF_30_CNT_SOCIAL_CIRCLE_sqrt']
# Columns with NaN values: ['DAYS_EMPLOYED_sqrt']

# %%
# Calculate the correlation matrix
corr = dff.corr()

# Plot the heatmap
plt.figure(figsize=(10, 3))
sns.heatmap(corr, annot=True, fmt=".2f",cmap="YlGnBu")
plt.show()

# %%
#Dropping amount credit sqrt as it has more above 1 correlation.

dff = dff.drop(columns=["AMT_CREDIT_x_sqrt"])

# %%
# !pip install imblearn
from imblearn.over_sampling import RandomOverSampler
# Out:
# Collecting imblearn
#   Downloading imblearn-0.0-py2.py3-none-any.whl.metadata (355 bytes)
# Requirement already satisfied: imbalanced-learn in c:\users\nandhini sivaramanan\anaconda3\lib\site-packages (from imblearn) (0.12.3)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\nandhini sivaramanan\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.26.4)
# Requirement already satisfied: scipy>=1.5.0 in c:\users\nandhini sivaramanan\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.13.1)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\users\nandhini sivaramanan\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.4.2)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\nandhini sivaramanan\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\nandhini sivaramanan\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (2.2.0)
# Downloading imblearn-0.0-py2.py3-none-any.whl (1.9 kB)
# Installing collected packages: imblearn
# Successfully installed imblearn-0.0

# %% [markdown]
# # MODEL BUILDING

# %%
values = dff.drop('TARGET', axis=1)
tar = dff['TARGET']

# %%
ro = RandomOverSampler(random_state= 40)

# %%
re_data, re_tar = ro.fit_resample(values, tar)
re_data['TARGET'] = re_tar
re_data['TARGET'].value_counts()
# Out:
# TARGET
# 1    865635
# 0    865635
# Name: count, dtype: int64

# %%
val = re_data.drop('TARGET', axis=1)
tar = re_data['TARGET']

# %%
X_train, X_test, y_train, y_test  = train_test_split(val, tar, test_size= 0.2, random_state=40)

# %%
dfg = df4[['AMT_INCOME_TOTAL_sqrt','CODE_GENDER_sqrt','FLAG_OWN_CAR_sqrt',
       'AMT_CREDIT_x_sqrt', 'AMT_ANNUITY_x_sqrt',
       'OCCUPATION_TYPE_sqrt', 'NAME_EDUCATION_TYPE_sqrt',
       'NAME_FAMILY_STATUS_sqrt','NAME_HOUSING_TYPE_sqrt',
       'OBS_30_CNT_SOCIAL_CIRCLE_sqrt', 'DEF_30_CNT_SOCIAL_CIRCLE_sqrt',"TARGET"]]

# %%
value = dfg.drop('TARGET', axis=1)
targ = dfg['TARGET']
ro = RandomOverSampler(random_state= 40)
re_data, re_tar = ro.fit_resample(value, targ)
re_data['TARGET'] = re_tar

# %%
va = re_data.drop('TARGET', axis=1)
ta = re_data['TARGET']
X1_train, X1_test, y1_train, y1_test  = train_test_split(va, ta, test_size= 0.2, random_state=40)

# %%
# Implementing the classifier models to check which is best

# %%
# KNNeighbors
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, confusion_matrix

knn = KNeighborsClassifier(n_neighbors=5)

# Fit the classifier
knn.fit(X1_train, y1_train)

# Predict the labels
y_pred = knn.predict(X1_test)

# Evaluate the classifier
accuracy = accuracy_score(y1_test, y_pred)
print(f"Accuracy: {accuracy}")
cm = confusion_matrix(y1_test, y_pred)
print(f"Confusion Matrix:\n{cm}")
# Out:
# Accuracy: 0.9790876062081594
# Confusion Matrix:
# [[166810   6340]
#  [   901 172203]]

# %%
#Since we found some constant & NaN values earlier in the df, for Overfitting verification we're checking train and test models accuracy.

# %%
y_pred_train = knn.predict(X1_train)
y_pred_test = knn.predict(X1_test)

# Step 3: Calculate accuracy
train_accuracy = accuracy_score(y1_train, y_pred_train)
test_accuracy = accuracy_score(y1_test, y_pred_test)

print(f'Training Accuracy: {train_accuracy}')
print(f'Test Accuracy: {test_accuracy}')
# Out:
# Training Accuracy: 0.9857604533088427
# Test Accuracy: 0.9790876062081594

# %%
#Train Accuracy is nearer to Test Accuracy with 0.01 difference so our model is not overfitting. Now we can proceed with the further evaluation

# %%
# Evalution Metrics
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
import matplotlib.pyplot as plt
print("Confusion Matrix:")
print(confusion_matrix(y1_test, y_pred))
print("Classification Report:")
print(classification_report(y1_test, y_pred))
false, true, thresholds = roc_curve(y1_test, y_pred)
roc_auc = auc(false, true)
plt.plot(false, true, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.show()
# Out:
# Confusion Matrix:
# [[166810   6340]
#  [   901 172203]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.96      0.98    173150
#            1       0.96      0.99      0.98    173104
#
#     accuracy                           0.98    346254
#    macro avg       0.98      0.98      0.98    346254
# weighted avg       0.98      0.98      0.98    346254

# %%
''' 'AMT_INCOME_TOTAL_sqrt','CODE_GENDER_sqrt','FLAG_OWN_CAR_sqrt',
       'AMT_CREDIT_x_sqrt', 'AMT_ANNUITY_x_sqrt',
       'OCCUPATION_TYPE_sqrt', 'NAME_EDUCATION_TYPE_sqrt',
       'NAME_FAMILY_STATUS_sqrt','NAME_HOUSING_TYPE_sqrt',
       'OBS_30_CNT_SOCIAL_CIRCLE_sqrt', 'DEF_30_CNT_SOCIAL_CIRCLE_sqrt',"TARGET" '''
# Out:
# ' \'AMT_INCOME_TOTAL_sqrt\',\'CODE_GENDER_sqrt\',\'FLAG_OWN_CAR_sqrt\',\n       \'AMT_CREDIT_x_sqrt\', \'AMT_ANNUITY_x_sqrt\',\n       \'OCCUPATION_TYPE_sqrt\', \'NAME_EDUCATION_TYPE_sqrt\',\n       \'NAME_FAMILY_STATUS_sqrt\',\'NAME_HOUSING_TYPE_sqrt\',\n       \'OBS_30_CNT_SOCIAL_CIRCLE_sqrt\', \'DEF_30_CNT_SOCIAL_CIRCLE_sqrt\',"TARGET" '

# %%
#Now checking with the sample values whether this model predicts the status

# %%
sample = np.array([[np.sqrt(135000.0),0,1,np.sqrt(312682.5),np.sqrt(29686.5),7,2,1,5,np.sqrt(1.0),np.sqrt (2.0)]])
pred = knn.predict(sample)
if pred==0:
    print('The status is: Repay')
else:
    print('The status is: Wont Repay')
# Out:
# The status is: Repay

# %%
sample = np.array([[np.sqrt(202500.0),0,1,np.sqrt(406597.5),np.sqrt(24700.5),8,0,3,7,np.sqrt(2.0),np.sqrt (2.0)]])
pred = knn.predict(sample)
if pred==0:
    print('The status is: Repay')
else:
    print('The status is: Wont Repay')
# Out:
# The status is: Wont Repay

# %%
# Decision tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.preprocessing import StandardScaler

scaler1 = StandardScaler()
X1_train_scaled = scaler1.fit_transform(X1_train)
X1_test_scaled = scaler1.transform(X1_test)

decision_tree = DecisionTreeClassifier(
    criterion='gini',
    max_depth=25,
    min_samples_split=5,
    min_samples_leaf=5
)

# Fit
decision_tree.fit(X1_train_scaled, y1_train)

# Predict the labels
y_pred = decision_tree.predict(X1_test_scaled)

# Evaluate the classifier
accuracy = accuracy_score(y1_test, y_pred)
print(f"Accuracy: {accuracy}")
cm = confusion_matrix(y1_test, y_pred)
print(f"Confusion Matrix:\n{cm}")
# Out:
# Accuracy: 0.9208326835213456
# Confusion Matrix:
# [[153050  20100]
#  [  7312 165792]]

# %%
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
import matplotlib.pyplot as plt
print("Confusion Matrix:")
print(confusion_matrix(y1_test, y_pred))
print("Classification Report:")
print(classification_report(y1_test, y_pred))
false, true, thresholds = roc_curve(y1_test, y_pred)
roc_auc = auc(false, true)
plt.plot(false, true, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')                                           #  DECISON TREE
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.show()
# Out:
# Confusion Matrix:
# [[153050  20100]
#  [  7312 165792]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.88      0.92    173150
#            1       0.89      0.96      0.92    173104
#
#     accuracy                           0.92    346254
#    macro avg       0.92      0.92      0.92    346254
# weighted avg       0.92      0.92      0.92    346254

# %%
# Random forest
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.preprocessing import StandardScaler
scaler2 = StandardScaler()
X1_train_scaled = scaler2.fit_transform(X1_train)
X1_test_scaled = scaler2.transform(X1_test)

random_forest = RandomForestClassifier(
    max_depth=18,
    min_samples_split=15,
    min_samples_leaf=8,
    criterion='gini',
    max_features='sqrt'
)

# Fit
random_forest.fit(X1_train_scaled, y1_train)

# Predict
y_pred_rf = random_forest.predict(X1_test_scaled)

# Evaluate the classifier
accuracy_rf = accuracy_score(y1_test, y_pred_rf)
print(f"Accuracy: {accuracy_rf}")
cm_rf = confusion_matrix(y1_test, y_pred_rf)
print(f"Confusion Matrix:\n{cm_rf}")
# Out:
# Accuracy: 0.9028574399140515
# Confusion Matrix:
# [[148957  24193]
#  [  9443 163661]]

# %%
# Evalution Metrics
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
import matplotlib.pyplot as plt
print("Confusion Matrix:")
print(confusion_matrix(y1_test, y_pred))
print("Classification Report:")
print(classification_report(y1_test, y_pred))
false, true, thresholds = roc_curve(y1_test, y_pred)
roc_auc = auc(false, true)
plt.plot(false, true, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.show()
# Out:
# Confusion Matrix:
# [[153050  20100]
#  [  7312 165792]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.88      0.92    173150
#            1       0.89      0.96      0.92    173104
#
#     accuracy                           0.92    346254
#    macro avg       0.92      0.92      0.92    346254
# weighted avg       0.92      0.92      0.92    346254

# %%
#XGBoost
from xgboost import XGBClassifier  
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.preprocessing import StandardScaler

scaler3 = StandardScaler()
X1_train_scaled = scaler3.fit_transform(X1_train)
X1_test_scaled = scaler3.transform(X1_test)

xgb = XGBClassifier(use_label_encoder=False, eval_metric='mlogloss',
                    n_estimators=550,
                    max_depth=8,
                    learning_rate=0.4,
                    subsample=0.9,
                    colsample_bytree=0.9)

# Fit
xgb.fit(X1_train_scaled, y1_train)

# Predict
y_pred = xgb.predict(X1_test_scaled)

# Evaluate the classifier
accuracy = accuracy_score(y1_test, y_pred)
print(f"Accuracy: {accuracy}")
cm = confusion_matrix(y1_test, y_pred)
print(f"Confusion Matrix:\n{cm}")
# Out:
# Accuracy: 0.9463313059199316
# Confusion Matrix:
# [[160235  12915]
#  [  5668 167436]]

# %%
# Evalution Metrics
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
import matplotlib.pyplot as plt
print("Confusion Matrix:")
print(confusion_matrix(y1_test, y_pred))
print("Classification Report:")
print(classification_report(y1_test, y_pred))

false, true, thresholds = roc_curve(y1_test, y_pred)
roc_auc = auc(false, true)
plt.plot(false, true, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.show()
# Out:
# Confusion Matrix:
# [[160235  12915]
#  [  5668 167436]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.93      0.95    173150
#            1       0.93      0.97      0.95    173104
#
#     accuracy                           0.95    346254
#    macro avg       0.95      0.95      0.95    346254
# weighted avg       0.95      0.95      0.95    346254

# %%
# Saving the model
import pickle
with open('knnmodel.pkl', 'wb') as file:
    pickle.dump(knn, file)

with open('dtmodel.pkl', 'wb') as file:
    pickle.dump(decision_tree, file)

with open('rfmodel.pkl', 'wb') as file:
    pickle.dump(random_forest, file)

with open('xgbmodel.pkl', 'wb') as file:
    pickle.dump(xgb, file)

# %%
with open('dtscaler.pkl', 'wb') as f:
    pickle.dump(scaler1, f)
with open('rfscaler.pkl', 'wb') as f:
    pickle.dump(scaler2, f)
with open('xgbscaler.pkl', 'wb') as f:
    pickle.dump(scaler3, f)

# %%
sample = np.array([[np.sqrt(202500.0),1,0,np.sqrt(406597.5),np.sqrt(24700.5),8,8,0,3,np.sqrt(2.0),np.sqrt (2.0)]])
pred = xgb.predict(sample)
if pred==1:
    print('The status is: Repay')
else:
    print('The status is: Wont Repay')
# Out:
# The status is: Wont Repay

# %% [markdown]
# - From the above analysis and evaluations, All ML models are performing well so we can use any one of the model for our default prediction process.
# - All our model scores(Accuracy, Precision, Recall & F1-score) are above 87% as per the above complete analysis.
# - For simpler purpose, I am taking KNN model for UI prediction.
# - Also in ROC summary, KNN provides the best classification performance with 0.98

# %%
#Save the final data in csv format
df4.to_csv('final_data.csv',index=False)
